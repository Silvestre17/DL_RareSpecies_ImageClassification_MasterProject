# %% [markdown]
# <div style="display: flex; align-items: center; justify-content: center; flex-wrap: wrap;">
#     <div style="flex: 1; max-width: 400px; display: flex; justify-content: center;">
#         <img src="https://i.ibb.co/JBPWVYR/Logo-Nova-IMS-Black.png" style="max-width: 50%; height: auto; margin-top: 50px; margin-bottom: 50px;margin-left: 6rem;">
#     </div>
#     <div style="flex: 2; text-align: center; margin-top: 20px;margin-left: 8rem;">
#         <div style="font-size: 28px; font-weight: bold; line-height: 1.2;">
#             <span style="color: #22c1c3;">DL Project |</span> <span style="color: #08529C;">Predicting Rare Species from Images using Deep Learning</span>
#         </div>
#         <div style="font-size: 17px; font-weight: bold; margin-top: 10px;">
#             Spring Semester | 2024 - 2025
#         </div>
#         <div style="font-size: 17px; font-weight: bold;">
#             Master in Data Science and Advanced Analytics
#         </div>
#         <div style="margin-top: 20px;">
#             <div>André Silvestre, 20240502</div>
#             <div>Diogo Duarte, 20240525</div>
#             <div>Filipa Pereira, 20240509</div>
#             <div>Maria Cruz, 20230760</div>
#             <div>Umeima Mahomed, 20240543</div>
#         </div>
#         <div style="margin-top: 20px; font-weight: bold;">
#             Group 37
#         </div>
#     </div>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(to right, #22c1c3, #27b1dd, #2d9cfd, #090979);
#             padding: 1px; color: white; border-radius: 500px; text-align: center;">
# </div>

# %% [markdown]
# ## **📚 Libraries Import**

# %%
# !pip install visualkeras
# Out:
# Collecting visualkeras
#   Downloading visualkeras-0.1.4-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from visualkeras) (11.1.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.11/dist-packages (from visualkeras) (2.0.2)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Downloading aggdraw-1.3.19-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (655 bytes)
# Downloading visualkeras-0.1.4-py3-none-any.whl (17 kB)
# Downloading aggdraw-1.3.19-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (997 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 997.4/997.4 kB 23.6 MB/s eta 0:00:00
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.19 visualkeras-0.1.4

# %%
# System imports
import os
import sys
import time
import datetime
from tqdm import tqdm
from typing_extensions import Self, Any      # For Python 3.10
# from typing import Self, Any               # For Python >3.11

from pathlib import Path

# Data manipulation imports
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# Data visualization imports
import matplotlib.pyplot as plt
import seaborn as sns

# Deep learning imports
import tensorflow as tf
from keras.ops import add
from keras.losses import CategoricalCrossentropy
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras import Model, Sequential, Input
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, LearningRateScheduler, EarlyStopping
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Rescaling, Lambda, BatchNormalization, Activation, GlobalAveragePooling2D
from tensorflow.keras import regularizers                                                                           # For L2 regularization
import visualkeras

# Evaluation imports
from keras.metrics import CategoricalAccuracy, AUC, F1Score, Precision, Recall

# Other imports
from itertools import product

# Set the style of the visualization
pd.set_option('future.no_silent_downcasting', True)   # use int instead of float in DataFrame
pd.set_option("display.max_columns", None)            # display all columns

# Disable warnings (FutureWarning)
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=UserWarning)

# Set random seed for reproducibility
np.random.seed(2025)

# %%
print("TensorFlow Version:", tf.__version__)
print("Is TensorFlow built with CUDA?", tf.test.is_built_with_cuda())
print("GPU Available:", tf.config.list_physical_devices('GPU'))
print("GPU Device Name:", tf.test.gpu_device_name())                                # (if error in Google Colab: Make sure your Hardware accelerator is set to GPU.
                                                                                    # Runtime > Change runtime type > Hardware Accelerator)
# Out:
# TensorFlow Version: 2.18.0
# Is TensorFlow built with CUDA? True
# GPU Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# GPU Device Name: /device:GPU:0

# %%
# Get build information from TensorFlow
build_info = tf.sysconfig.get_build_info()

print("TensorFlow version:", tf.__version__)
print("Python version:", sys.version)
print("CUDA version:", build_info.get("cuda_version", "Not available"))
print("cuDNN version:", build_info.get("cudnn_version", "Not available"))
# Out:
# TensorFlow version: 2.18.0
# Python version: 3.11.12 (main, Apr  9 2025, 08:55:54) [GCC 11.4.0]
# CUDA version: 12.5.1
# cuDNN version: 9

# %%
# Import custom module for importing data, visualization, and utilities
import utilities

# %% [markdown]
# <div style="background: linear-gradient(to right, #22c1c3, #27b1dd, #2d9cfd, #090979);
#             padding: 1px; color: white; border-radius: 500px; text-align: center;">
# </div>

# %% [markdown]
# ## **🧮 Import Databases**

# %%
# Run in Google Collab to download the dataset already splitted
# Source: https://stackoverflow.com/questions/25010369/wget-curl-large-file-from-google-drivez
# Download the file from Google Drive using wget
# !wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate \
  "https://drive.usercontent.google.com/download?id=1dmr2cGxgM-kp1aXlmd9cQzVCkcl4JTFo&export=download" -O- | \
  sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p' > /tmp/confirm.txt

# Read the confirmation token from the temporary file
with open('/tmp/confirm.txt', 'r') as f:
    confirm_token = f.read().strip()

# Download the file using the confirmation token and cookies
# !wget --load-cookies /tmp/cookies.txt \
  "https://drive.usercontent.google.com/download?id=1dmr2cGxgM-kp1aXlmd9cQzVCkcl4JTFo&export=download&confirm={confirm_token}" \
  -O /content/RareSpecies_Split.zip

# Clean up temporary files
# !rm /tmp/cookies.txt /tmp/confirm.txt

# List files in the /content directory to verify the download
# !ls -lh /content/

# Unzip the downloaded file
# !unzip /content/RareSpecies_Split.zip -d /content/

# List the unzipped files to verify
# !ls -lh /content/
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
#   inflating: /content/RareSpecies_Split/train/chordata_scombridae/22410740_46577312_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_scombridae/22410733_46577312_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_scombridae/24577118_46577312_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_scombridae/22410743_46577312_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_scombridae/22410741_46577312_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_scombridae/29105239_46577312_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_scombridae/22410746_46577312_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_scombridae/24577117_46577312_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_scombridae/22410732_46577312_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_scombridae/27656351_46577312_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_scombridae/27656349_46577312_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_scombridae/24577120_46577312_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_scombridae/22410735_46577312_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_scombridae/22410731_46577312_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_scombridae/14133967_46577312_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_scombridae/27656350_46577312_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_scombridae/22410736_46577312_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_scombridae/29105236_46577312_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_scombridae/24577115_46577312_eol-full-size-copy.jpg
#    creating: /content/RareSpecies_Split/train/chordata_diplodactylidae/
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/2720416_47047493_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/2720398_47047493_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/22121746_791386_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/2720434_47047493_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/2738829_791386_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/22121754_791386_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/2720436_47047493_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/2738831_791386_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/22269574_47047493_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/22121745_791386_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/2720401_47047493_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/22269560_47047493_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/22121747_791386_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/22121758_791386_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/2738825_791386_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/22121760_791386_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/22121749_791386_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/2720417_47047493_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/22121759_791386_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/29624402_47047493_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/29626490_791386_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/2720413_47047493_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/22121751_791386_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/22121744_791386_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/29624397_47047493_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/2720419_47047493_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/2720439_47047493_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/2720405_47047493_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/22121755_791386_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/22121753_791386_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/2720407_47047493_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/22121752_791386_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/22269570_47047493_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/22269565_47047493_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/2720432_47047493_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/2720399_47047493_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/2720389_47047493_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/22269575_47047493_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/2738830_791386_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/22121762_791386_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/2738824_791386_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/22121748_791386_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/2738827_791386_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/2738828_791386_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/2720441_47047493_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/22269569_47047493_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/2720430_47047493_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_diplodactylidae/2720426_47047493_eol-full-size-copy.jpg
#    creating: /content/RareSpecies_Split/train/chordata_ardeidae/
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/22496140_1049004_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/22496133_1049004_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/22496130_1049004_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/22240808_45517756_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/28769259_45517756_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/22240820_45517756_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/29727658_1049004_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/22496127_1049004_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/22240807_45517756_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/22240818_45517756_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/22496143_1049004_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/22240813_45517756_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/22240809_45517756_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/30030964_45517756_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/14103234_1049004_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/22240819_45517756_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/30030973_45517756_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/22240815_45517756_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/22496128_1049004_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/29727651_1049004_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/22496134_1049004_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/22240814_45517756_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/22240810_45517756_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/30030972_45517756_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/30030969_45517756_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/22496132_1049004_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/22496139_1049004_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/2698_45517756_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/30030968_45517756_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/30030966_45517756_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/29727652_1049004_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/30030970_45517756_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/14103235_1049004_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/22240801_45517756_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/22496129_1049004_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/30030967_45517756_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/29727659_1049004_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/30030975_45517756_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/22496125_1049004_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/22496145_1049004_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/22240806_45517756_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/30030974_45517756_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/22496141_1049004_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/22240804_45517756_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/22240812_45517756_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/22496144_1049004_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/14103232_1049004_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_ardeidae/22496137_1049004_eol-full-size-copy.jpg
#    creating: /content/RareSpecies_Split/train/chordata_vangidae/
#   inflating: /content/RareSpecies_Split/train/chordata_vangidae/28914704_45514240_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_vangidae/21288506_45514240_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_vangidae/21288501_45514240_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_vangidae/28914701_45514240_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_vangidae/21288503_45514240_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_vangidae/21288495_45514240_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_vangidae/21288500_45514240_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_vangidae/28914698_45514240_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_vangidae/21288509_45514240_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_vangidae/28914696_45514240_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_vangidae/16263_45514240_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_vangidae/21288504_45514240_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_vangidae/28914697_45514240_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_vangidae/28914702_45514240_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_vangidae/21288502_45514240_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_vangidae/28765144_45514240_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_vangidae/28765143_45514240_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_vangidae/28914699_45514240_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_vangidae/21288508_45514240_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_vangidae/21288498_45514240_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_vangidae/28914700_45514240_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_vangidae/21288497_45514240_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_vangidae/16228_45514240_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_vangidae/28914693_45514240_eol-full-size-copy.jpg
#    creating: /content/RareSpecies_Split/train/chordata_alligatoridae/
#   inflating: /content/RareSpecies_Split/train/chordata_alligatoridae/22252277_1055872_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_alligatoridae/29802963_1055872_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_alligatoridae/13986095_1055872_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_alligatoridae/22252280_1055872_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_alligatoridae/29802958_1055872_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_alligatoridae/13986098_1055872_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_alligatoridae/2757398_1055872_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_alligatoridae/28477231_1055872_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_alligatoridae/13986102_1055872_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_alligatoridae/2757396_1055872_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_alligatoridae/22252290_1055872_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_alligatoridae/29802965_1055872_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_alligatoridae/29802952_1055872_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_alligatoridae/29802959_1055872_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_alligatoridae/29802951_1055872_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_alligatoridae/13596222_1055872_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_alligatoridae/22252291_1055872_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_alligatoridae/2757397_1055872_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_alligatoridae/13986100_1055872_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_alligatoridae/29802956_1055872_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_alligatoridae/29802954_1055872_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_alligatoridae/22252293_1055872_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_alligatoridae/28477232_1055872_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_alligatoridae/22252289_1055872_eol-full-size-copy.jpg
#    creating: /content/RareSpecies_Split/train/chordata_cebidae/
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/14015331_4453333_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/29377095_4453333_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/29900910_4453305_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/29468547_4453294_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/22730721_4453305_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/21933594_4453294_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/29468517_4453294_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/29900920_4453305_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/22730715_4453305_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/29900916_4453305_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/29468523_4453294_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/29377090_4453333_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/20577179_4453333_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/29468513_4453294_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/29468543_4453294_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/29468522_4453294_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/21933589_4453294_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/21933585_4453294_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/21933587_4453294_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/29377089_4453333_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/22730726_4453305_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/29377093_4453333_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/21933591_4453294_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/14015327_4453333_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/20577190_4453333_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/29468604_4453294_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/20577189_4453333_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/28509768_4453305_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/20577176_4453333_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/22730728_4453305_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/29468590_4453294_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/29468600_4453294_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/20577183_4453333_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/14015329_4453333_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/29377099_4453333_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/14015321_4453333_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/22730711_4453305_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/29900912_4453305_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/29900919_4453305_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/20577178_4453333_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/29468509_4453294_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/29900913_4453305_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/29900921_4453305_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/29468518_4453294_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/29468560_4453294_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/29468512_4453294_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/22730731_4453305_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/29468565_4453294_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/22730720_4453305_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/22730716_4453305_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/28509771_4453305_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/22730714_4453305_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/29377084_4453333_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/29468553_4453294_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/29468576_4453294_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/28509769_4453305_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/29468581_4453294_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/20577177_4453333_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/22730718_4453305_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/29468569_4453294_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/29468574_4453294_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/29900917_4453305_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/20577188_4453333_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/22730730_4453305_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/20577182_4453333_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/22730725_4453305_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/20577181_4453333_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/29377091_4453333_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/14015332_4453333_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/22730722_4453305_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/29468606_4453294_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cebidae/21933586_4453294_eol-full-size-copy.jpg
#    creating: /content/RareSpecies_Split/train/chordata_percidae/
#   inflating: /content/RareSpecies_Split/train/chordata_percidae/21186973_211786_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_percidae/21186972_211786_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_percidae/21186965_211786_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_percidae/21186971_211786_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_percidae/21186976_211786_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_percidae/21186963_211786_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_percidae/21186964_211786_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_percidae/2702991_211786_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_percidae/21186968_211786_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_percidae/21186966_211786_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_percidae/2702990_211786_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_percidae/2702994_211786_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_percidae/2703000_211786_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_percidae/2702995_211786_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_percidae/2702993_211786_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_percidae/21186970_211786_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_percidae/2703001_211786_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_percidae/21186961_211786_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_percidae/28479013_211786_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_percidae/2702998_211786_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_percidae/2702988_211786_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_percidae/29882896_211786_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_percidae/21186958_211786_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_percidae/21186974_211786_eol-full-size-copy.jpg
#    creating: /content/RareSpecies_Split/train/chordata_rhacophoridae/
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/29536731_1048330_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/29536723_1048330_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/29543404_1018932_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/22753133_1048330_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/22753135_1048330_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/29543405_1018932_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/21051960_1018932_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/29543400_1018932_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/29543401_1018932_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/22753137_1048330_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/21051976_1018932_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/29543402_1018932_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/22753136_1048330_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/21051964_1018932_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/22753131_1048330_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/29543399_1018932_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/29536728_1048330_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/29536724_1048330_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/29543410_1018932_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/21051961_1018932_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/21051974_1018932_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/29543413_1018932_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/29536721_1048330_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/21051962_1018932_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/22753139_1048330_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/29543416_1018932_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/22753126_1048330_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/22753141_1048330_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/21051977_1018932_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/22753140_1048330_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/29536718_1048330_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/22753145_1048330_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/29543415_1018932_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/8758235_1018932_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/22753125_1048330_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/29536722_1048330_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/29536730_1048330_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/22753129_1048330_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/22753128_1048330_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/21051970_1018932_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/22753144_1048330_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/22753142_1048330_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/14009197_1018932_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/14009198_1018932_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/21051958_1018932_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/21051969_1018932_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/29543406_1018932_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_rhacophoridae/21051967_1018932_eol-full-size-copy.jpg
#    creating: /content/RareSpecies_Split/train/cnidaria_acroporidae/
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28274688_45276283_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28219382_45276311_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28261329_45276299_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/20870190_45276283_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28355694_45276219_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/20197412_45276321_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28250728_45276321_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28219374_45276311_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28343284_45276323_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/29729258_45276299_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28250727_45276321_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/29729260_45276299_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/20197410_45276321_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/20991864_45276219_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28274639_45276283_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28261331_45276299_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/29674756_45276219_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/12281676_45276283_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/20197409_45276321_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/29674749_45276219_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28219383_45276311_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28261346_45276299_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28274671_45276283_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/20991878_45276219_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28261332_45276299_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/29729518_45276300_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/20870175_45276283_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/20991875_45276219_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/29729568_45276321_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/20870185_45276283_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/20991876_45276219_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/29729257_45276299_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/20197411_45276321_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28343271_45276323_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/22147228_45276300_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28261325_45276299_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/20991865_45276219_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28274652_45276283_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/20197419_45276321_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/20991867_45276219_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28274702_45276283_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/20197405_45276321_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28274682_45276283_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28261338_45276299_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28343294_45276323_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28219393_45276311_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/29729263_45276299_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28261330_45276299_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/20991869_45276219_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/29729390_45276311_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/29907289_45276283_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/29729264_45276299_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28219385_45276311_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28343274_45276323_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28219392_45276311_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28219386_45276311_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28261343_45276299_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28274647_45276283_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28343268_45276323_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/29907293_45276283_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28261335_45276299_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28343280_45276323_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/29674751_45276219_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/20197420_45276321_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28261326_45276299_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/21611334_45276323_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/29907294_45276283_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/29674750_45276219_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28274691_45276283_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/22147242_45276300_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28343281_45276323_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/20991870_45276219_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28343270_45276323_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/14217129_45276300_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28343269_45276323_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/29729259_45276299_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/29729517_45276300_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28219399_45276311_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/22147234_45276300_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28343292_45276323_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/22147247_45276300_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/21611332_45276323_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/22147235_45276300_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/29729522_45276300_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28343277_45276323_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/29729570_45276321_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28183631_45276300_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/14217128_45276300_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28261347_45276299_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/22147227_45276300_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28250729_45276321_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/20991868_45276219_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28219371_45276311_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/29729261_45276299_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28274606_45276283_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/20991871_45276219_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/20991880_45276219_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28219391_45276311_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/29729566_45276321_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/29674752_45276219_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28343295_45276323_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28261348_45276299_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/22147244_45276300_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28274714_45276283_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28219376_45276311_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28274642_45276283_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/29729569_45276321_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28274656_45276283_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28219401_45276311_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28219366_45276311_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28219387_45276311_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28274715_45276283_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28261345_45276299_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/20991863_45276219_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/20197408_45276321_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/29907290_45276283_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28343290_45276323_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/20991872_45276219_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28261339_45276299_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28219381_45276311_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28343287_45276323_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28219375_45276311_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/29729564_45276321_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/29674754_45276219_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28274617_45276283_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/20870179_45276283_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/29729262_45276299_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/20197414_45276321_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/cnidaria_acroporidae/28274632_45276283_eol-full-size-copy.jpg
# ...
#   inflating: /content/RareSpecies_Split/train/chordata_dalatiidae/20642998_46560177_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_dalatiidae/20642990_46560177_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_dalatiidae/24589787_46560177_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_dalatiidae/28971559_46560177_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_dalatiidae/28478411_46560177_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_dalatiidae/28478403_46560177_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_dalatiidae/20642995_46560177_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_dalatiidae/28478416_46560177_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_dalatiidae/12313003_46560177_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_dalatiidae/20642996_46560177_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_dalatiidae/28971565_46560177_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_dalatiidae/10605398_46560177_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_dalatiidae/20643000_46560177_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_dalatiidae/20642989_46560177_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_dalatiidae/20642991_46560177_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_dalatiidae/30167054_46560177_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_dalatiidae/30167053_46560177_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_dalatiidae/28478409_46560177_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_dalatiidae/28478410_46560177_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_dalatiidae/30167056_46560177_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_dalatiidae/20642987_46560177_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_dalatiidae/30167052_46560177_eol-full-size-copy.jpg
#    creating: /content/RareSpecies_Split/train/chordata_cracidae/
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/22618625_45512036_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/22132970_45512039_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/29500876_45512036_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/22132967_45512039_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/22618630_45512036_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/22132971_45512039_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/14020651_45512039_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/22132968_45512039_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/22618627_45512036_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/29500877_45512036_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/14020646_45512039_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/22132964_45512039_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/22132974_45512039_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/22618637_45512036_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/29415844_45512039_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/22618631_45512036_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/29500879_45512036_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/14085628_45512036_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/8830622_45512036_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/22132972_45512039_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/29415845_45512039_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/14020650_45512039_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/8830625_45512036_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/22132965_45512039_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/14085629_45512036_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/29500883_45512036_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/22132978_45512039_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/22132963_45512039_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/22132962_45512039_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/8830620_45512036_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/8830624_45512036_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/29500871_45512036_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/22132977_45512039_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/29415842_45512039_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/8830621_45512036_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/29500880_45512036_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/8830623_45512036_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/22618624_45512036_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/22618635_45512036_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/22132976_45512039_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/29415846_45512039_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/29500873_45512036_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/22132961_45512039_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/22132969_45512039_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/29500870_45512036_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/22618633_45512036_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/22618622_45512036_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cracidae/22132979_45512039_eol-full-size-copy.jpg
#    creating: /content/RareSpecies_Split/train/chordata_cervidae/
#   inflating: /content/RareSpecies_Split/train/chordata_cervidae/14164357_308403_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cervidae/29400554_308403_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cervidae/22814117_308403_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cervidae/15265085_308403_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cervidae/15265079_308403_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cervidae/22814115_308403_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cervidae/29400557_308403_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cervidae/15265089_308403_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cervidae/15265077_308403_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cervidae/29400552_308403_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cervidae/22814113_308403_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cervidae/29400559_308403_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cervidae/22814128_308403_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cervidae/22814114_308403_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cervidae/15265084_308403_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cervidae/15265090_308403_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cervidae/22814122_308403_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cervidae/29400553_308403_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cervidae/29400551_308403_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cervidae/8899455_308403_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cervidae/15265082_308403_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cervidae/15265087_308403_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cervidae/14164359_308403_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_cervidae/8899451_308403_eol-full-size-copy.jpg
#    creating: /content/RareSpecies_Split/train/chordata_balaenidae/
#   inflating: /content/RareSpecies_Split/train/chordata_balaenidae/29364680_46559421_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_balaenidae/28510307_46559421_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_balaenidae/29364674_46559421_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_balaenidae/29364686_46559421_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_balaenidae/20140559_46559421_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_balaenidae/29364697_46559421_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_balaenidae/20140558_46559421_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_balaenidae/29364687_46559421_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_balaenidae/28510290_46559421_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_balaenidae/29364684_46559421_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_balaenidae/28510295_46559421_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_balaenidae/28510292_46559421_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_balaenidae/28510293_46559421_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_balaenidae/29364690_46559421_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_balaenidae/20140543_46559421_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_balaenidae/29364688_46559421_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_balaenidae/29364693_46559421_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_balaenidae/29364698_46559421_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_balaenidae/20140548_46559421_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_balaenidae/28510296_46559421_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_balaenidae/28510298_46559421_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_balaenidae/29364668_46559421_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_balaenidae/28510304_46559421_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_balaenidae/14735022_46559421_eol-full-size-copy.jpg
#    creating: /content/RareSpecies_Split/train/chordata_otididae/
#   inflating: /content/RareSpecies_Split/train/chordata_otididae/22137135_45513870_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_otididae/22137143_45513870_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_otididae/30075874_45513870_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_otididae/14162238_45513870_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_otididae/30075872_45513870_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_otididae/22137136_45513870_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_otididae/14162240_45513870_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_otididae/22137152_45513870_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_otididae/22137140_45513870_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_otididae/22137142_45513870_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_otididae/14162239_45513870_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_otididae/22137149_45513870_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_otididae/22137134_45513870_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_otididae/22137133_45513870_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_otididae/22137141_45513870_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_otididae/22137146_45513870_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_otididae/14162237_45513870_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_otididae/22137144_45513870_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_otididae/14162232_45513870_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_otididae/22137139_45513870_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_otididae/30075875_45513870_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_otididae/30075876_45513870_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_otididae/22137151_45513870_eol-full-size-copy.jpg
#   inflating: /content/RareSpecies_Split/train/chordata_otididae/22137137_45513870_eol-full-size-copy.jpg
# total 7.7G
# drwxr-xr-x 2 root root 4.0K Apr 14 22:10 ModelCallbacks
# drwxr-xr-x 2 root root 4.0K Apr 14 22:10 ModelsEvaluation
# drwxr-xr-x 2 root root 4.0K Apr 14 22:10 __pycache__
# drwxr-xr-x 6 root root 4.0K Apr 13 16:54 RareSpecies_Split
# -rw-r--r-- 1 root root 7.7G Apr 13 17:42 RareSpecies_Split.zip
# drwxr-xr-x 1 root root 4.0K Apr 11 13:37 sample_data
# -rw-r--r-- 1 root root  21K Apr 14 22:06 utilities.py

# %%
# Define the path to the data
# train_dir = Path("data/RareSpecies_Split/train")
# val_dir = Path("data/RareSpecies_Split/val")
# test_dir = Path("data/RareSpecies_Split/test")

# For Google Collab
train_dir = Path("/content/RareSpecies_Split/train")
val_dir = Path("/content/RareSpecies_Split/val")
test_dir = Path("/content/RareSpecies_Split/test")

# %%
# Image Generators
n_classes = 202                                     # Number of classes (we already know this based on previous notebook)
image_size = (224, 224)                             # Image size (224x224)
img_height, img_width = image_size                  # Image dimensions
batch_size = 64                                     # Batch size
input_shape = (img_height, img_width, 3)            # Input shape of the model
value_range = (0.0, 1.0)                            # Range of pixel values

# %%
# Get class names from directory
class_names = sorted(os.listdir(train_dir))
class_indices = {name: i for i, name in enumerate(class_names)}

# Import the image dataset from the directory
from utilities import load_images_from_directory
train_datagen, val_datagen, test_datagen = load_images_from_directory(train_dir, val_dir, test_dir,
                                                                      labels='inferred', label_mode='categorical',
                                                                      class_names=class_names, color_mode='rgb',
                                                                      batch_size=batch_size, image_size=image_size, seed=2025,
                                                                      interpolation='bilinear', crop_to_aspect_ratio=False, pad_to_aspect_ratio=False)

print(f"\nLoaded: Train ({train_datagen.cardinality().numpy() * batch_size}), "
        f"Val ({val_datagen.cardinality().numpy() * batch_size}), "
        f"Test ({test_datagen.cardinality().numpy() * batch_size})")
# Out:
# Found 9586 files belonging to 202 classes.
# Found 1198 files belonging to 202 classes.
# Found 1199 files belonging to 202 classes.
#
# Loaded: Train (9600), Val (1216), Test (1216)

# %%
# Check the shape of the data (batch_size, img_width, img_height, 3)
for x, y in train_datagen.take(1):
    print("Train batch shape:", x.shape, y.shape)
for x, y in val_datagen.take(1):
    print("Val batch shape:", x.shape, y.shape)
for x, y in test_datagen.take(1):
    print("Test batch shape:", x.shape, y.shape)

# %% [markdown]
# # <a class='anchor' id='3'></a>
# <br>
# <style>
# @import url('https://fonts.cdnfonts.com/css/avenir-next-lt-pro?styles=29974');
# </style>
#
# <div style="background: linear-gradient(to right, #22c1c3, #27b1dd, #2d9cfd, #090979);
#             padding: 10px; color: white; border-radius: 300px; text-align: center;">
#     <center><h1 style="margin-left: 140px;margin-top: 10px; margin-bottom: 4px; color: white;
#                        font-size: 32px; font-family: 'Avenir Next LT Pro', sans-serif;">
#         <b>3 | Modeling - Baseline Model</b></h1></center>
# </div>
#
# <br><br>

# %% [markdown]
# # **💡 Modeling**

# %%
# Baseline Model
class RareSpeciesCNN(Model):
    """Custom CNN for rare species classification.

    Architecture: Simple CNN
    Why: Small model to establish baseline, avoiding overfitting on 202 classes.
    Alternatives: Deeper CNNs (e.g., ResNet) or transfer learning (e.g., EfficientNet).
    Allows selection of preprocessing steps like grayscale, contrast, and saturation adjustment.
    """
    def __init__(self, n_classes=202,                                   # Number of output classes
                 apply_grayscale=False,                                 # If True, convert images to grayscale
                 apply_contrast=False, contrast_factor=1.5,             # 1.5 = increase contrast
                 apply_saturation=False, saturation_factor=1.5):        # 1.5 = increase saturation
        """Initializes the model.

        Args:
            n_classes (int): Number of output classes.
            apply_grayscale (bool): If True, convert images to grayscale first.
            apply_contrast (bool): If True, adjust image contrast.
            contrast_factor (float): Factor for contrast adjustment.
            apply_saturation (bool): If True, adjust image saturation.
            saturation_factor (float): Factor for saturation adjustment.
        """
        super().__init__() # Call the parent class constructor

        # Store preprocessing flags and factors
        self.apply_grayscale = apply_grayscale
        self.apply_contrast = apply_contrast
        self.apply_saturation = apply_saturation

        # --- Preprocessing Layers ---
        # Rescaling layer (always applied)
        self.rescale_layer = Rescaling(scale= 1 / 255.0, name="Rescale_Layer")    # Rescales pixel values to [0, 1]

        # Conditionally define Lambda layer for contrast adjustment
        if self.apply_contrast:
            # Define Lambda layer for contrast adjustment
            # Source: https://keras.io/api/layers/core_layers/lambda/
            #         https://www.tensorflow.org/api_docs/python/tf/image/adjust_contrast
            #         contrast_factor > 1 increases contrast, < 1 decreases contrast
            self.contrast_layer = Lambda(
                lambda x: tf.image.adjust_contrast(x, contrast_factor=contrast_factor),
                name='Adjust_Contrast'
            )

        # Conditionally define Lambda layer for saturation adjustment
        if self.apply_saturation:
            # Define Lambda layer for saturation adjustment
            # Source: https://www.tensorflow.org/api_docs/python/tf/image/adjust_saturation
            #         saturation_factor > 1 increases saturation, < 1 decreases saturation
            self.saturation_layer = Lambda(
                lambda x: tf.image.adjust_saturation(x, saturation_factor=saturation_factor),
                name='Adjust_Saturation'
            )

        # Conditionally define Lambda layer for grayscale conversion
        if self.apply_grayscale:
            # Define Lambda layer for grayscale conversion
            # Source: https://www.tensorflow.org/api_docs/python/tf/image/rgb_to_grayscale
            self.grayscale_layer = Lambda(
                lambda x: tf.image.rgb_to_grayscale(x),
                name='RGB_to_Grayscale'
            )
            # IMPORTANT: Add a Conv2D layer immediately after grayscale to ensure
            #            the number of channels is compatible with subsequent layers
            #            if they expect 3 channels. Here, we'll keep it 1 channel and adjust conv1.
            # Alternatively, convert grayscale back to 3 identical channels:
            # self.grayscale_to_rgb_layer = Lambda(
            #     lambda x: tf.image.grayscale_to_rgb(x),
            #     name='Grayscale_to_RGB'
            # )


        # --- Convolutional Layers ---
        # Adjust the first Conv layer's input channels if grayscale is applied and not converted back to RGB
        # If grayscale IS applied, the input to conv1 will have 1 channel.
        # If grayscale IS NOT applied, the input will have 3 channels (after rescaling).
        # We will handle this by checking the shape dynamically or assuming subsequent layers can handle 1 channel if needed.
        # For simplicity here, let's assume conv1 works with either 1 or 3 channels.
        # If grayscale is applied, the input depth is 1, otherwise 3.
        # A more robust way might involve explicitly setting input_shape or checking channels.
        # Let's define conv1 to work even if input is grayscale (1 channel)

        # Block 1
        # Source: https://stackoverflow.com/questions/60157742/convolutional-neural-network-cnn-input-shape/61075207#61075207 (Explain Conv2D)
        self.conv1 = Conv2D(filters=32, kernel_size=(3, 3), padding='same', kernel_regularizer=regularizers.l2(0.001), name="Conv_Block1_Conv")
        self.bn1 = BatchNormalization(name="Conv_Block1_BN")
        self.act1 = Activation('relu', name="Conv_Block1_Act")
        self.pool1 = MaxPooling2D(pool_size=(2, 2), name="Conv_Block1_Pool") # Output: 112x112x32

        # Block 2
        self.conv2 = Conv2D(filters=64, kernel_size=(3, 3), padding='same',kernel_regularizer=regularizers.l2(0.001), name="Conv_Block2_Conv")
        self.bn2 = BatchNormalization(name="Conv_Block2_BN")
        self.act2 = Activation('relu', name="Conv_Block2_Act")
        self.pool2 = MaxPooling2D(pool_size=(2, 2), name="Conv_Block2_Pool") # Output: 56x56x64

        # Block 3
        self.conv3 = Conv2D(filters=128, kernel_size=(3, 3), padding='same',kernel_regularizer=regularizers.l2(0.001), name="Conv_Block3_Conv")
        self.bn3 = BatchNormalization(name="Conv_Block3_BN")
        self.act3 = Activation('relu', name="Conv_Block3_Act")
        self.pool3 = MaxPooling2D(pool_size=(2, 2), name="Conv_Block3_Pool") # Output: 28x28x128

        ### Block 4
        self.conv4 = Conv2D(filters=256, kernel_size=(3, 3), padding='same',kernel_regularizer=regularizers.l2(0.001), name="Conv_Block4_Conv") # Increased filters
        self.bn4 = BatchNormalization(name="Conv_Block4_BN")
        self.act4 = Activation('relu', name="Conv_Block4_Act")
        self.pool4 = MaxPooling2D(pool_size=(2, 2), name="Conv_Block4_Pool") # Output: 14x14x256

        # --- Classification Head ---
        self.global_avg_pool = GlobalAveragePooling2D(name="Global_Average_Pooling")
        ###self.flatten = Flatten(name="Flatten_Layer")
        self.dense1 = Dense(128, name="Dense_Layer1")                                     # Smaller intermediate dense layer
        self.bn_dense1 = BatchNormalization(name="Dense_Layer1_BN")
        self.act_dense1 = Activation('relu', name="Dense_Layer1_Act")
        self.dropout = Dropout(0.5, name="Dropout_Layer") ###dropout era 0.7
        self.dense_output = Dense(n_classes, activation='softmax', name="Output_Layer")

    def call(self: Self, inputs: Any, training:bool=False) -> Any:
        """Defines the forward pass of the model.

        Args:
            inputs: Input tensor (batch of images).
            training (bool): Indicates if the model is in training mode (for Dropout).

        Returns:
            Output tensor (probabilities for each class).
        """
        # Apply mandatory rescaling
        x = self.rescale_layer(inputs)

        # Apply conditional preprocessing layers
        if self.apply_contrast:
            x = self.contrast_layer(x)
        if self.apply_saturation:
            x = self.saturation_layer(x)
        if self.apply_grayscale:
            x = self.grayscale_layer(x)
            # If subsequent layers strictly require 3 channels, uncomment this:
            # x = self.grayscale_to_rgb_layer(x)
            # Note: If grayscale is applied, conv1 will process a 1-channel input unless converted back.

        # Conv Block 1
        x = self.conv1(x)
        x = self.bn1(x, training=training)
        x = self.act1(x)
        x = self.pool1(x)

        # Conv Block 2
        x = self.conv2(x)
        x = self.bn2(x, training=training)
        x = self.act2(x)
        x = self.pool2(x)

        # Conv Block 3
        x = self.conv3(x)
        x = self.bn3(x, training=training)
        x = self.act3(x)
        x = self.pool3(x)

        ### Conv Block 4
        x = self.conv4(x)
        x = self.bn4(x, training=training)
        x = self.act4(x)
        x = self.pool4(x)

        # Classification Head
        x = self.global_avg_pool(x)
        ###x = self.flatten(x)
        x = self.dense1(x)
        x = self.bn_dense1(x, training=training)
        x = self.act_dense1(x)
        x = self.dropout(x, training=training)
        outputs = self.dense_output(x)

        return outputs

# Example Instantiation and Summary
model = RareSpeciesCNN(
    n_classes=n_classes,
    apply_grayscale=False,
    apply_contrast=False,
    apply_saturation=False,
)

# Build the model by providing an input shape
inputs = Input(shape=(img_width, img_height, 3))        # Input shape
_ = model.call(inputs)                                  # Call the model to build it
model.summary()                                         # Print the model summary
# Out:
# Model: "rare_species_cnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Rescale_Layer (Rescaling)       │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block1_Conv (Conv2D)       │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block1_BN                  │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block1_Act (Activation)    │ (None, 224, 224, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block1_Pool (MaxPooling2D) │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block2_Conv (Conv2D)       │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block2_BN                  │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block2_Act (Activation)    │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block2_Pool (MaxPooling2D) │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block3_Conv (Conv2D)       │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block3_BN                  │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block3_Act (Activation)    │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block3_Pool (MaxPooling2D) │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block4_Conv (Conv2D)       │ (None, 28, 28, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block4_BN                  │ (None, 28, 28, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block4_Act (Activation)    │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block4_Pool (MaxPooling2D) │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Global_Average_Pooling          │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dense_Layer1 (Dense)            │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dense_Layer1_BN                 │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dense_Layer1_Act (Activation)   │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dropout_Layer (Dropout)         │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output_Layer (Dense)            │ (None, 202)            │        26,058 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 449,802 (1.72 MB)
#  Trainable params: 448,586 (1.71 MB)
#  Non-trainable params: 1,216 (4.75 KB)

# %%
# Visualize the model architecture
# Source: https://www.kaggle.com/code/devsubhash/visualize-deep-learning-models-using-visualkeras
visualkeras.layered_view(model,
                         legend=True,
                         show_dimension=True,
                         scale_xy=1,                                        # Adjust the scale of the image
                        #  scale_z=1,
                         # to_file='./BaselineModel_Architecture.png',
)

# %%
# Compile model
# optimizer = SGD(learning_rate=0.1, weight_decay=0.01, name="Optimizer")                                         # SGD with decay for stability
optimizer = Adam(learning_rate=0.001, weight_decay=0.01, name="Optimizer")                                        # Adam for faster convergence

loss = CategoricalCrossentropy(name="Loss")                                                                       # Suitable for multi-class one-hot labels
metrics = [CategoricalAccuracy(name="accuracy"),
           Precision(name="precision"),
           Recall(name="recall"),
           F1Score(average="macro", name="f1_score"),
           AUC(name="auc")]
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# %%
# Create a directory for saving the model and logs
model_name = f"RareSpeciesCNN_{datetime.datetime.now().strftime('%Y%m%d')}"                                                                             # Model name
print(f"\n\033[1mModel name:\033[0m {model_name}")

# %%
from keras.callbacks import ReduceLROnPlateau


# Callbacks
# Create a directory for saving the model and logs
os.makedirs("./ModelCallbacks", exist_ok=True)      # Create directory if it doesn't exist
model_name = f"RareSpeciesCNN_{datetime.datetime.now().strftime('%Y%m%d')}"                                                                             # Model name
callbacks = [
    ModelCheckpoint(f"./ModelCallbacks/checkpoint_{model_name}.keras", monitor="val_loss", save_best_only=True, verbose=0),       # Save best model
    CSVLogger(f"./ModelCallbacks/metrics_{model_name}.csv"),                                                                      # Log training metrics
    LearningRateScheduler(lambda epoch, lr: lr * 0.95), # Exponential decay for learning rate
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=1),
    EarlyStopping(monitor='val_loss', patience=5, verbose=1, restore_best_weights=True)                                                                      # Stop training when the validation loss stops improving
]

# %% [markdown]
# ---

# %% [markdown]
# ### **Original Dataset | Grayscale=F | Contrast=F | Saturation=F**

# %%
# Train model
start_time = time.time()
history = model.fit(train_datagen, batch_size = batch_size, epochs=10, validation_data=val_datagen, callbacks=callbacks, verbose=1)
train_time = round(time.time() - start_time, 2)

print(f"\nTraining completed in \033[1m{train_time} seconds ({str(datetime.timedelta(seconds=train_time))} h)\033[0m).")

# %% [markdown]
# ##### **🧪 Model Selection & 📏 Model Evaluation**

# %%
# Evaluate model
from utilities import plot_metrics

os.makedirs("./ModelsEvaluation", exist_ok=True)                                              # Create directory if it doesn't exist
plot_metrics(history, file_path=f"./ModelsEvaluation/2_Training_Validation_Metrics_{datetime.datetime.now().strftime('%Y%m%d')}.png")

# %%
# Evaluate on validation and test sets
train_results = {'accuracy': history.history['accuracy'][-1], 'precision': history.history['precision'][-1], 'recall': history.history['recall'][-1], 'f1_score': history.history['f1_score'][-1], 'auc': history.history['auc'][-1]}
val_results = model.evaluate(val_datagen, batch_size=batch_size, return_dict=True, verbose=1)
test_results = model.evaluate(test_datagen, batch_size=batch_size, return_dict=True, verbose=1)

# %%
# Display results
from utilities import display_side_by_side, create_evaluation_dataframe
results_df = create_evaluation_dataframe(
    model_name="Baseline Model",
    variation="Original | Grayscale=F | Contrast=F | Saturation=F | Adam=0.001",           # Dataset | Grayscale | Contrast | Saturation | Optimizer=Learning Rate
    train_metrics=train_results, val_metrics=val_results, test_metrics=test_results, train_time=train_time,
    csv_save_path= f"./ModelsEvaluation/2_BaselineModel_TrainingValidationMetrics_{model_name}.csv"      # Save the results to a CSV file
)
display_side_by_side(results_df, super_title="Model Evaluation Results")

# %% [markdown]
# ---

# %% [markdown]
# ## **Original Dataset | Grayscale=T | Contrast=F | Saturation=F**

# %%
# Model - Original Dataset | Grayscale=T | Contrast=F | Saturation=F
model = RareSpeciesCNN(
    n_classes=n_classes,
    apply_grayscale=True,
    apply_contrast=False,
    apply_saturation=False
)

# Build the model by providing an input shape
inputs = Input(shape=(img_width, img_height, 3))        # Input shape
_ = model.call(inputs)                                  # Call the model to build it
model.summary()                                         # Print the model summary

# %%
# Compile model
# optimizer = SGD(learning_rate=0.1, weight_decay=0.01, name="Optimizer")                                         # SGD with decay for stability
optimizer = Adam(learning_rate=0.001, weight_decay=0.01, name="Optimizer")                                        # Adam for faster convergence

loss = CategoricalCrossentropy(name="Loss")                                                                       # Suitable for multi-class one-hot labels
metrics = [CategoricalAccuracy(name="accuracy"), Precision(name="precision"), Recall(name="recall"), F1Score(average="macro", name="f1_score"), AUC(name="auc")]
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# %%
# Callbacks
model_name = f"RareSpeciesCNN_{datetime.datetime.now().strftime('%Y%m%d')}_OriginalGrayscale" # Model name
callbacks = [ModelCheckpoint(f"./ModelCallbacks/checkpoint_{model_name}.keras", monitor="val_loss", save_best_only=True, verbose=0), CSVLogger(f"./ModelCallbacks/metrics_{model_name}.csv"), LearningRateScheduler(lambda epoch, lr: lr * 0.95), EarlyStopping(monitor='val_loss', patience=5, verbose=1)]

# %%
# Train model
start_time = time.time()
history = model.fit(train_datagen, batch_size = batch_size, epochs=10, validation_data=val_datagen, callbacks=callbacks, verbose=1)
train_time = round(time.time() - start_time, 2)
print(f"\nTraining completed in \033[1m{train_time} seconds ({str(datetime.timedelta(seconds=train_time))} h)\033[0m).")

# %% [markdown]
# ##### **🧪 Model Selection & 📏 Model Evaluation**

# %%
# Evaluate model
from utilities import plot_metrics
plot_metrics(history, file_path=f"./ModelsEvaluation/2_BaselineModel_TrainingValidationMetrics_{model_name}.png")

# %%
# Evaluate on validation and test sets
train_results = {'accuracy': history.history['accuracy'][-1], 'precision': history.history['precision'][-1], 'recall': history.history['recall'][-1], 'f1_score': history.history['f1_score'][-1], 'auc': history.history['auc'][-1]}
val_results = model.evaluate(val_datagen, batch_size=batch_size, return_dict=True, verbose=1)
test_results = model.evaluate(test_datagen, batch_size=batch_size, return_dict=True, verbose=1)

# Display results
from utilities import display_side_by_side, create_evaluation_dataframe
results_df = create_evaluation_dataframe(
    model_name="Baseline Model", variation="Original | Grayscale=T | Contrast=F | Saturation=F | Adam=0.001",   # Dataset | Grayscale | Contrast | Saturation | Optimizer=Learning Rate
    train_metrics=train_results, val_metrics=val_results, test_metrics=test_results, train_time=train_time,
    csv_save_path= f"./ModelsEvaluation/2_BaselineModel_TrainingValidationMetrics_{model_name}.csv"
)
display_side_by_side(results_df, super_title="Model Evaluation Results")

# %% [markdown]
# ---

# %% [markdown]
# ## **Original Dataset | Grayscale=F | Contrast=T | Saturation=F**

# %%
# Model - Original Dataset | Grayscale=F | Contrast=T | Saturation=F
model = RareSpeciesCNN(
    n_classes=n_classes,
    apply_grayscale=False,
    apply_contrast=True,
    apply_saturation=False
)
# Build the model by providing an input shape
inputs = Input(shape=(img_width, img_height, 3))        # Input shape
_ = model.call(inputs)                                  # Call the model to build it
model.summary()                                         # Print the model summary
# Out:
# Model: "rare_species_cnn_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Rescale_Layer (Rescaling)       │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Adjust_Contrast (Lambda)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block1_Conv (Conv2D)       │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block1_BN                  │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block1_Act (Activation)    │ (None, 224, 224, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block1_Pool (MaxPooling2D) │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block2_Conv (Conv2D)       │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block2_BN                  │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block2_Act (Activation)    │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block2_Pool (MaxPooling2D) │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block3_Conv (Conv2D)       │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block3_BN                  │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block3_Act (Activation)    │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block3_Pool (MaxPooling2D) │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block4_Conv (Conv2D)       │ (None, 28, 28, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block4_BN                  │ (None, 28, 28, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block4_Act (Activation)    │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block4_Pool (MaxPooling2D) │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Global_Average_Pooling          │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dense_Layer1 (Dense)            │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dense_Layer1_BN                 │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dense_Layer1_Act (Activation)   │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dropout_Layer (Dropout)         │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output_Layer (Dense)            │ (None, 202)            │        26,058 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 449,802 (1.72 MB)
#  Trainable params: 448,586 (1.71 MB)
#  Non-trainable params: 1,216 (4.75 KB)

# %%
# Compile model
# optimizer = SGD(learning_rate=0.1, weight_decay=0.01, name="Optimizer")                                         # SGD with decay for stability
optimizer = Adam(learning_rate=0.001, weight_decay=0.01, name="Optimizer")                                        # Adam for faster convergence
loss = CategoricalCrossentropy(name="Loss")                                                                       # Suitable for multi-class one-hot labels
metrics = [CategoricalAccuracy(name="accuracy"), Precision(name="precision"), Recall(name="recall"), F1Score(average="macro", name="f1_score"), AUC(name="auc")]
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# %%
# Callbacks
model_name = f"RareSpeciesCNN_{datetime.datetime.now().strftime('%Y%m%d')}_OriginalContrast" # Model name
callbacks = [ModelCheckpoint(f"./ModelCallbacks/checkpoint_{model_name}.keras", monitor="val_loss", save_best_only=True, verbose=0), CSVLogger(f"./ModelCallbacks/metrics_{model_name}.csv"), LearningRateScheduler(lambda epoch, lr: lr * 0.95), EarlyStopping(monitor='val_loss', patience=5, verbose=1)]

# Train model
start_time = time.time()
history = model.fit(train_datagen, batch_size = batch_size, epochs=10, validation_data=val_datagen, callbacks=callbacks, verbose=1)
train_time = round(time.time() - start_time, 2)
print(f"\nTraining completed in \033[1m{train_time} seconds ({str(datetime.timedelta(seconds=train_time))} h)\033[0m).")
# Out:
# Epoch 1/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 198s 1s/step - accuracy: 0.0395 - auc: 0.6107 - f1_score: 0.0073 - loss: 5.5503 - precision: 0.1816 - recall: 6.5255e-04 - val_accuracy: 0.0217 - val_auc: 0.6309 - val_f1_score: 0.0012 - val_loss: 5.5972 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 9.5000e-04
# Epoch 2/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 170s 1s/step - accuracy: 0.0814 - auc: 0.7204 - f1_score: 0.0125 - loss: 5.0044 - precision: 0.3244 - recall: 0.0025 - val_accuracy: 0.0534 - val_auc: 0.6746 - val_f1_score: 0.0049 - val_loss: 5.2142 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 9.0250e-04
# Epoch 3/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 167s 1s/step - accuracy: 0.0890 - auc: 0.7510 - f1_score: 0.0166 - loss: 4.8023 - precision: 0.4427 - recall: 0.0037 - val_accuracy: 0.0693 - val_auc: 0.7267 - val_f1_score: 0.0051 - val_loss: 4.8826 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 8.5737e-04
# Epoch 4/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 198s 1s/step - accuracy: 0.1042 - auc: 0.7801 - f1_score: 0.0228 - loss: 4.6034 - precision: 0.6147 - recall: 0.0076 - val_accuracy: 0.1002 - val_auc: 0.7765 - val_f1_score: 0.0168 - val_loss: 4.5662 - val_precision: 0.5833 - val_recall: 0.0058 - learning_rate: 8.1451e-04
# Epoch 5/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 200s 1s/step - accuracy: 0.1124 - auc: 0.7955 - f1_score: 0.0320 - loss: 4.4655 - precision: 0.6765 - recall: 0.0115 - val_accuracy: 0.1068 - val_auc: 0.7700 - val_f1_score: 0.0265 - val_loss: 4.6124 - val_precision: 0.5000 - val_recall: 0.0042 - learning_rate: 7.7378e-04
# Epoch 6/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 202s 1s/step - accuracy: 0.1230 - auc: 0.8125 - f1_score: 0.0354 - loss: 4.3495 - precision: 0.6797 - recall: 0.0162 - val_accuracy: 0.1119 - val_auc: 0.7820 - val_f1_score: 0.0275 - val_loss: 4.5112 - val_precision: 0.7500 - val_recall: 0.0075 - learning_rate: 7.3509e-04
# Epoch 7/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 165s 1s/step - accuracy: 0.1314 - auc: 0.8211 - f1_score: 0.0410 - loss: 4.2560 - precision: 0.7291 - recall: 0.0160 - val_accuracy: 0.1386 - val_auc: 0.8069 - val_f1_score: 0.0420 - val_loss: 4.3034 - val_precision: 0.6923 - val_recall: 0.0075 - learning_rate: 6.9834e-04
# Epoch 8/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 162s 1s/step - accuracy: 0.1416 - auc: 0.8296 - f1_score: 0.0481 - loss: 4.1835 - precision: 0.7305 - recall: 0.0222 - val_accuracy: 0.1244 - val_auc: 0.7659 - val_f1_score: 0.0324 - val_loss: 4.5622 - val_precision: 0.7812 - val_recall: 0.0209 - learning_rate: 6.6342e-04
# Epoch 9/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 159s 1s/step - accuracy: 0.1444 - auc: 0.8340 - f1_score: 0.0568 - loss: 4.1480 - precision: 0.6926 - recall: 0.0236 - val_accuracy: 0.1494 - val_auc: 0.8264 - val_f1_score: 0.0452 - val_loss: 4.1684 - val_precision: 0.7419 - val_recall: 0.0192 - learning_rate: 6.3025e-04
# Epoch 10/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 154s 1s/step - accuracy: 0.1496 - auc: 0.8460 - f1_score: 0.0589 - loss: 4.0563 - precision: 0.7697 - recall: 0.0283 - val_accuracy: 0.1494 - val_auc: 0.8310 - val_f1_score: 0.0584 - val_loss: 4.1011 - val_precision: 0.8205 - val_recall: 0.0267 - learning_rate: 5.9874e-04
#
# Training completed in 1774.98 seconds (0:29:34.980000 h)).

# %% [markdown]
# #### **🧪 Model Selection & 📏 Model Evaluation**

# %%
# Evaluate model
from utilities import plot_metrics
plot_metrics(history, file_path=f"./ModelsEvaluation/2_BaselineModel_TrainingValidationMetrics_{model_name}.png")

# %%
# Evaluate on validation and test sets
train_results = {'accuracy': history.history['accuracy'][-1], 'precision': history.history['precision'][-1], 'recall': history.history['recall'][-1], 'f1_score': history.history['f1_score'][-1], 'auc': history.history['auc'][-1]}
val_results = model.evaluate(val_datagen, batch_size=batch_size, return_dict=True, verbose=1)
test_results = model.evaluate(test_datagen, batch_size=batch_size, return_dict=True, verbose=1)

# Display results
from utilities import display_side_by_side, create_evaluation_dataframe
results_df = create_evaluation_dataframe(
    model_name="Baseline Model", variation="Original | Grayscale=F | Contrast=T | Saturation=F | Adam=0.001",   # Dataset | Grayscale | Contrast | Saturation | Optimizer=Learning Rate
    train_metrics=train_results, val_metrics=val_results, test_metrics=test_results, train_time=train_time,
    csv_save_path= f"./ModelsEvaluation/2_BaselineModel_TrainingValidationMetrics_{model_name}.csv"
)
display_side_by_side(results_df, super_title="Model Evaluation Results")
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.2007 - auc: 0.8410 - f1_score: 0.0338 - loss: 3.9379 - precision: 0.8617 - recall: 0.0482
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.2003 - auc: 0.8530 - f1_score: 0.0283 - loss: 3.9588 - precision: 0.8498 - recall: 0.0472
# <h1 style="text-align: left; margin-bottom: -15px;">Model Evaluation Results</h1><br><div style="display: flex;"><div style="margin-right: 20px;"><h3 style="text-align: center;color:#555555;"></h3><table style="display:inline; margin-right: 20px;" border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th colspan="5" halign="left">Train</th>
#       <th colspan="5" halign="left">Validation</th>
#       <th colspan="5" halign="left">Test</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>Time of Execution</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1 Score</th>
#       <th>AUROC</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1 Score</th>
#       <th>AUROC</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1 Score</th>
#       <th>AUROC</th>
#     </tr>
#     <tr>
#       <th>Model</th>
#       <th>Variation</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Baseline Model</th>
#       <th>Original | Grayscale=F | Contrast=T | Saturation=F | Adam=0.001</th>
#       <td>1774.98</td>
#       <td>0.1469</td>
#       <td>0.7564</td>
#       <td>0.0275</td>
#       <td>0.0621</td>
#       <td>0.8437</td>
#       <td>0.1494</td>
#       <td>0.8205</td>
#       <td>0.0267</td>
#       <td>0.0584</td>
#       <td>0.831</td>
#       <td>0.1501</td>
#       <td>0.775</td>
#       <td>0.0259</td>
#       <td>0.0422</td>
#       <td>0.8361</td>
#     </tr>
#   </tbody>
# </table style="display:inline; margin-right: 20px;"></div></div>

# %% [markdown]
# ---

# %% [markdown]
# ## **Original Dataset | Grayscale=F | Contrast=F | Saturation=T**

# %%
# Model - Original Dataset | Grayscale=F | Contrast=F | Saturation=T
model = RareSpeciesCNN(
    n_classes=n_classes,
    apply_grayscale=False,
    apply_contrast=False,
    apply_saturation=True
)

# Build the model by providing an input shape
inputs = Input(shape=(img_width, img_height, 3))        # Input shape
_ = model.call(inputs)                                  # Call the model to build it
model.summary()                                         # Print the model summary
# Out:
# Model: "rare_species_cnn_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Rescale_Layer (Rescaling)       │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Adjust_Saturation (Lambda)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block1_Conv (Conv2D)       │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block1_BN                  │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block1_Act (Activation)    │ (None, 224, 224, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block1_Pool (MaxPooling2D) │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block2_Conv (Conv2D)       │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block2_BN                  │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block2_Act (Activation)    │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block2_Pool (MaxPooling2D) │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block3_Conv (Conv2D)       │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block3_BN                  │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block3_Act (Activation)    │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block3_Pool (MaxPooling2D) │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block4_Conv (Conv2D)       │ (None, 28, 28, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block4_BN                  │ (None, 28, 28, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block4_Act (Activation)    │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block4_Pool (MaxPooling2D) │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Global_Average_Pooling          │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dense_Layer1 (Dense)            │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dense_Layer1_BN                 │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dense_Layer1_Act (Activation)   │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dropout_Layer (Dropout)         │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output_Layer (Dense)            │ (None, 202)            │        26,058 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 449,802 (1.72 MB)
#  Trainable params: 448,586 (1.71 MB)
#  Non-trainable params: 1,216 (4.75 KB)

# %%
# Compile model
# optimizer = SGD(learning_rate=0.1, weight_decay=0.01, name="Optimizer")                                         # SGD with decay for stability
optimizer = Adam(learning_rate=0.001, weight_decay=0.01, name="Optimizer")                                        # Adam for faster convergence
loss = CategoricalCrossentropy(name="Loss")                                                                       # Suitable for multi-class one-hot labels
metrics = [CategoricalAccuracy(name="accuracy"), Precision(name="precision"), Recall(name="recall"), F1Score(average="macro", name="f1_score"), AUC(name="auc")]
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# %%
# Callbacks
model_name = f"RareSpeciesCNN_{datetime.datetime.now().strftime('%Y%m%d')}_OriginalSaturation" # Model name
callbacks = [ModelCheckpoint(f"./ModelCallbacks/checkpoint_{model_name}.keras", monitor="val_loss", save_best_only=True, verbose=0), CSVLogger(f"./ModelCallbacks/metrics_{model_name}.csv"), LearningRateScheduler(lambda epoch, lr: lr * 0.95), EarlyStopping(monitor='val_loss', patience=5, verbose=1)]

# Train model
start_time = time.time()
history = model.fit(train_datagen, batch_size = batch_size, epochs=10, validation_data=val_datagen, callbacks=callbacks, verbose=1)
train_time = round(time.time() - start_time, 2)
print(f"\nTraining completed in \033[1m{train_time} seconds ({str(datetime.timedelta(seconds=train_time))} h)\033[0m).")
# Out:
# Epoch 1/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 180s 1s/step - accuracy: 0.0441 - auc: 0.6042 - f1_score: 0.0070 - loss: 5.5501 - precision: 0.1347 - recall: 6.1494e-04 - val_accuracy: 0.0250 - val_auc: 0.6412 - val_f1_score: 4.4879e-04 - val_loss: 5.4323 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 9.5000e-04
# Epoch 2/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 187s 1s/step - accuracy: 0.0810 - auc: 0.7293 - f1_score: 0.0128 - loss: 4.9912 - precision: 0.2893 - recall: 0.0018 - val_accuracy: 0.0359 - val_auc: 0.6491 - val_f1_score: 0.0023 - val_loss: 5.4547 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 9.0250e-04
# Epoch 3/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 160s 1s/step - accuracy: 0.0947 - auc: 0.7583 - f1_score: 0.0172 - loss: 4.7696 - precision: 0.5273 - recall: 0.0057 - val_accuracy: 0.0902 - val_auc: 0.7293 - val_f1_score: 0.0124 - val_loss: 4.8565 - val_precision: 0.4118 - val_recall: 0.0058 - learning_rate: 8.5737e-04
# Epoch 4/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 160s 1s/step - accuracy: 0.0998 - auc: 0.7731 - f1_score: 0.0212 - loss: 4.6319 - precision: 0.5043 - recall: 0.0062 - val_accuracy: 0.1077 - val_auc: 0.7772 - val_f1_score: 0.0189 - val_loss: 4.6180 - val_precision: 0.6667 - val_recall: 0.0050 - learning_rate: 8.1451e-04
# Epoch 5/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 154s 1s/step - accuracy: 0.1164 - auc: 0.7926 - f1_score: 0.0288 - loss: 4.4871 - precision: 0.6210 - recall: 0.0075 - val_accuracy: 0.1194 - val_auc: 0.7984 - val_f1_score: 0.0270 - val_loss: 4.4529 - val_precision: 0.6250 - val_recall: 0.0083 - learning_rate: 7.7378e-04
# Epoch 6/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 210s 1s/step - accuracy: 0.1191 - auc: 0.8057 - f1_score: 0.0330 - loss: 4.3969 - precision: 0.6507 - recall: 0.0108 - val_accuracy: 0.1419 - val_auc: 0.8060 - val_f1_score: 0.0335 - val_loss: 4.4047 - val_precision: 0.4444 - val_recall: 0.0033 - learning_rate: 7.3509e-04
# Epoch 7/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 196s 1s/step - accuracy: 0.1334 - auc: 0.8129 - f1_score: 0.0421 - loss: 4.3173 - precision: 0.7086 - recall: 0.0149 - val_accuracy: 0.1486 - val_auc: 0.8197 - val_f1_score: 0.0446 - val_loss: 4.2475 - val_precision: 0.5000 - val_recall: 8.3472e-04 - learning_rate: 6.9834e-04
# Epoch 8/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 167s 1s/step - accuracy: 0.1358 - auc: 0.8238 - f1_score: 0.0434 - loss: 4.2424 - precision: 0.7939 - recall: 0.0190 - val_accuracy: 0.1444 - val_auc: 0.8215 - val_f1_score: 0.0429 - val_loss: 4.2202 - val_precision: 0.7895 - val_recall: 0.0125 - learning_rate: 6.6342e-04
# Epoch 9/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 203s 1s/step - accuracy: 0.1322 - auc: 0.8288 - f1_score: 0.0469 - loss: 4.1943 - precision: 0.7327 - recall: 0.0205 - val_accuracy: 0.1536 - val_auc: 0.8219 - val_f1_score: 0.0632 - val_loss: 4.2323 - val_precision: 0.6667 - val_recall: 0.0067 - learning_rate: 6.3025e-04
# Epoch 10/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 192s 1s/step - accuracy: 0.1504 - auc: 0.8375 - f1_score: 0.0537 - loss: 4.1130 - precision: 0.7441 - recall: 0.0235 - val_accuracy: 0.1628 - val_auc: 0.8264 - val_f1_score: 0.0563 - val_loss: 4.1423 - val_precision: 0.8261 - val_recall: 0.0159 - learning_rate: 5.9874e-04
#
# Training completed in 1809.01 seconds (0:30:09.010000 h)).

# %% [markdown]
# ### **🧪 Model Selection & 📏 Model Evaluation**

# %%
# Evaluate model
from utilities import plot_metrics
plot_metrics(history, file_path=f"./ModelsEvaluation/2_BaselineModel_TrainingValidationMetrics_{model_name}.png")

# %%
# Evaluate on validation and test sets
train_results = {'accuracy': history.history['accuracy'][-1], 'precision': history.history['precision'][-1], 'recall': history.history['recall'][-1], 'f1_score': history.history['f1_score'][-1], 'auc': history.history['auc'][-1]}
val_results = model.evaluate(val_datagen, batch_size=batch_size, return_dict=True, verbose=1)
test_results = model.evaluate(test_datagen, batch_size=batch_size, return_dict=True, verbose=1)

# Display results
from utilities import display_side_by_side, create_evaluation_dataframe
results_df = create_evaluation_dataframe(
    model_name="Baseline Model", variation="Original | Grayscale=F | Contrast=F | Saturation=T | Adam=0.001",   # Dataset | Grayscale | Contrast | Saturation | Optimizer=Learning Rate
    train_metrics=train_results, val_metrics=val_results, test_metrics=test_results, train_time=train_time,
    csv_save_path= f"./ModelsEvaluation/2_BaselineModel_TrainingValidationMetrics_{model_name}.csv"
)
display_side_by_side(results_df, super_title="Model Evaluation Results")
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 18s 979ms/step - accuracy: 0.2122 - auc: 0.8351 - f1_score: 0.0360 - loss: 4.0163 - precision: 0.8467 - recall: 0.0143
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 18s 958ms/step - accuracy: 0.1962 - auc: 0.8396 - f1_score: 0.0328 - loss: 4.0116 - precision: 0.9088 - recall: 0.0195
# <h1 style="text-align: left; margin-bottom: -15px;">Model Evaluation Results</h1><br><div style="display: flex;"><div style="margin-right: 20px;"><h3 style="text-align: center;color:#555555;"></h3><table style="display:inline; margin-right: 20px;" border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th colspan="5" halign="left">Train</th>
#       <th colspan="5" halign="left">Validation</th>
#       <th colspan="5" halign="left">Test</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>Time of Execution</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1 Score</th>
#       <th>AUROC</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1 Score</th>
#       <th>AUROC</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1 Score</th>
#       <th>AUROC</th>
#     </tr>
#     <tr>
#       <th>Model</th>
#       <th>Variation</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Baseline Model</th>
#       <th>Original | Grayscale=F | Contrast=F | Saturation=T | Adam=0.001</th>
#       <td>1809.01</td>
#       <td>0.1433</td>
#       <td>0.7314</td>
#       <td>0.0216</td>
#       <td>0.054</td>
#       <td>0.8337</td>
#       <td>0.1628</td>
#       <td>0.8261</td>
#       <td>0.0159</td>
#       <td>0.0563</td>
#       <td>0.8264</td>
#       <td>0.156</td>
#       <td>0.9048</td>
#       <td>0.0158</td>
#       <td>0.0512</td>
#       <td>0.8272</td>
#     </tr>
#   </tbody>
# </table style="display:inline; margin-right: 20px;"></div></div>

# %% [markdown]
# ---

# %% [markdown]
# # **🖌️ SMOTE (Dataset Augmentation)**

# %%
# Load train data with Data Augmentation (SMOTE)
from utilities import load_images_from_directory

train_DataAugmentationSMOTE_dir = Path("data/RareSpecies_Split/train_DataAugmentationSMOTE")
val_dir = Path("data/RareSpecies_Split/val")
test_dir = Path("data/RareSpecies_Split/test")

class_names = sorted(os.listdir(train_DataAugmentationSMOTE_dir))
class_indices = {name: i for i, name in enumerate(class_names)}

# Import the image dataset from the directory
train_DataAugmentationSMOTE_datagen, val_datagen, test_datagen = load_images_from_directory(train_DataAugmentationSMOTE_dir, val_dir, test_dir,
                                                                      labels='inferred', label_mode='categorical',
                                                                      class_names=class_names, color_mode='rgb',
                                                                      batch_size=batch_size, image_size=image_size, seed=2025,
                                                                      interpolation='bilinear', crop_to_aspect_ratio=False, pad_to_aspect_ratio=False)

# Check the shape of the data (batch_size, img_width, img_height, 3)
for x, y in train_DataAugmentationSMOTE_datagen.take(1):
    print("Train batch shape:", x.shape, y.shape)
for x, y in val_datagen.take(1):
    print("Val batch shape:", x.shape, y.shape)
for x, y in test_datagen.take(1):
    print("Test batch shape:", x.shape, y.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-9701a2f705e9> in <cell line: 0>()
#       6 test_dir = Path("data/RareSpecies_Split/test")
#       7
# ----> 8 class_names = sorted(os.listdir(train_DataAugmentationSMOTE_dir))
#       9 class_indices = {name: i for i, name in enumerate(class_names)}
#      10
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/RareSpecies_Split/train_DataAugmentationSMOTE'

# %%
# Check class distribution
train_class_counts = {class_name: len(list((train_DataAugmentationSMOTE_dir / class_name).glob('*')))
                      for class_name in list(class_names)}
train_class_distribution = pd.DataFrame({
    'n': train_class_counts.values(),
    '%': [count / sum(train_class_counts.values()) * 100 for count in train_class_counts.values()],
})
train_class_distribution

# %% [markdown]
# ## **SMOTE Data Augmentation | Grayscale=F | Contrast=F | Saturation=F**

# %%
# Model - SMOTE Data Augmentation | Grayscale=F | Contrast=F | Saturation=F
model = RareSpeciesCNN(
    n_classes=n_classes,
    apply_grayscale=False,
    apply_contrast=False,
    apply_saturation=False
)

# Build the model by providing an input shape
inputs = Input(shape=(img_width, img_height, 3))        # Input shape
_ = model.call(inputs)                                  # Call the model to build it
model.summary()                                         # Print the model summary

# %%
# Compile model
optimizer = Adam(learning_rate=0.001, weight_decay=0.01, name="Optimizer")
loss = CategoricalCrossentropy(name="Loss")
metrics = [CategoricalAccuracy(name="accuracy"), Precision(name="precision"), Recall(name="recall"), F1Score(average="macro", name="f1_score"), AUC(name="auc")]
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# %%
# Callbacks
model_name = f"RareSpeciesCNN_{datetime.datetime.now().strftime('%Y%m%d')}_SMOTE"
callbacks = [ModelCheckpoint(f"./ModelCallbacks/checkpoint_{model_name}.keras", monitor="val_loss", save_best_only=True, verbose=0), CSVLogger(f"./ModelCallbacks/metrics_{model_name}.csv"), LearningRateScheduler(lambda epoch, lr: lr * 0.95), EarlyStopping(monitor='val_loss', patience=5, verbose=1)]

# Train model
start_time = time.time()
history = model.fit(train_DataAugmentationSMOTE_datagen, batch_size=batch_size, epochs=10, validation_data=val_datagen, callbacks=callbacks, verbose=1)
train_time = round(time.time() - start_time, 2)
print(f"\nTraining completed in \033[1m{train_time} seconds ({str(datetime.timedelta(seconds=train_time))} h)\033[0m).")

# %% [markdown]
# #### **🧪 Model Selection & 📏 Model Evaluation**

# %%
# Evaluate model
from utilities import plot_metrics
plot_metrics(history, file_path=f"./ModelsEvaluation/2_BaselineModel_TrainingValidationMetrics_{model_name}.png")

# %%
# Evaluate on validation and test sets
train_results = {'accuracy': history.history['accuracy'][-1], 'precision': history.history['precision'][-1], 'recall': history.history['recall'][-1], 'f1_score': history.history['f1_score'][-1], 'auc': history.history['auc'][-1]}
val_results = model.evaluate(val_datagen, batch_size=batch_size, return_dict=True, verbose=1)
test_results = model.evaluate(test_datagen, batch_size=batch_size, return_dict=True, verbose=1)

# Display results
from utilities import display_side_by_side, create_evaluation_dataframe
results_df = create_evaluation_dataframe(
    model_name="Baseline Model", variation="SMOTE | Grayscale=F | Contrast=F | Saturation=F | Adam=0.001",
    train_metrics=train_results, val_metrics=val_results, test_metrics=test_results, train_time=train_time,
    csv_save_path= f"./ModelsEvaluation/2_BaselineModel_TrainingValidationMetrics_{model_name}.csv"
)
display_side_by_side(results_df, super_title="Model Evaluation Results")

# %% [markdown]
# ---

# %% [markdown]
# ## **SMOTE Data Augmentation | Grayscale=T | Contrast=F | Saturation=F**

# %%
# Model - SMOTE Data Augmentation | Grayscale=T | Contrast=F | Saturation=F
model = RareSpeciesCNN(
    n_classes=n_classes,
    apply_grayscale=True,
    apply_contrast=False,
    apply_saturation=False
)

# Build the model by providing an input shape
inputs = Input(shape=(img_width, img_height, 3))        # Input shape
_ = model.call(inputs)                                  # Call the model to build it
model.summary()                                         # Print the model summary

# %%
# Compile model
optimizer = Adam(learning_rate=0.001, weight_decay=0.01, name="Optimizer")
loss = CategoricalCrossentropy(name="Loss")
metrics = [CategoricalAccuracy(name="accuracy"), Precision(name="precision"), Recall(name="recall"), F1Score(average="macro", name="f1_score"), AUC(name="auc")]
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# %%
# Callbacks
model_name = f"RareSpeciesCNN_{datetime.datetime.now().strftime('%Y%m%d')}_SMOTEGrayscale"
callbacks = [ModelCheckpoint(f"./ModelCallbacks/checkpoint_{model_name}.keras", monitor="val_loss", save_best_only=True, verbose=0), CSVLogger(f"./ModelCallbacks/metrics_{model_name}.csv"), LearningRateScheduler(lambda epoch, lr: lr * 0.95), EarlyStopping(monitor='val_loss', patience=5, verbose=1)]

# Train model
start_time = time.time()
history = model.fit(train_DataAugmentationSMOTE_datagen, batch_size=batch_size, epochs=10, validation_data=val_datagen, callbacks=callbacks, verbose=1)
train_time = round(time.time() - start_time, 2)
print(f"\nTraining completed in \033[1m{train_time} seconds ({str(datetime.timedelta(seconds=train_time))} h)\033[0m).")

# %% [markdown]
# #### **🧪 Model Selection & 📏 Model Evaluation**

# %%
# Evaluate model
from utilities import plot_metrics
plot_metrics(history, file_path=f"./ModelsEvaluation/2_BaselineModel_TrainingValidationMetrics_{model_name}.png")

# %%
# Evaluate on validation and test sets
train_results = {'accuracy': history.history['accuracy'][-1], 'precision': history.history['precision'][-1], 'recall': history.history['recall'][-1], 'f1_score': history.history['f1_score'][-1], 'auc': history.history['auc'][-1]}
val_results = model.evaluate(val_datagen, batch_size=batch_size, return_dict=True, verbose=1)
test_results = model.evaluate(test_datagen, batch_size=batch_size, return_dict=True, verbose=1)

# Display results
from utilities import display_side_by_side, create_evaluation_dataframe
results_df = create_evaluation_dataframe(
    model_name="Baseline Model", variation="SMOTE | Grayscale=T | Contrast=F | Saturation=F | Adam=0.001",
    train_metrics=train_results, val_metrics=val_results, test_metrics=test_results, train_time=train_time,
    csv_save_path= f"./ModelsEvaluation/2_BaselineModel_TrainingValidationMetrics_{model_name}.csv"
)
display_side_by_side(results_df, super_title="Model Evaluation Results")

# %% [markdown]
# ---

# %% [markdown]
# ## **SMOTE Data Augmentation | Grayscale=F | Contrast=T | Saturation=F**

# %%
# Model - SMOTE Data Augmentation | Grayscale=F | Contrast=T | Saturation=F
model = RareSpeciesCNN(
    n_classes=n_classes,
    apply_grayscale=False,
    apply_contrast=True,
    apply_saturation=False
)

# Build the model by providing an input shape
inputs = Input(shape=(img_width, img_height, 3))        # Input shape
_ = model.call(inputs)                                  # Call the model to build it
model.summary()                                         # Print the model summary

# %%
# Compile model
optimizer = Adam(learning_rate=0.001, weight_decay=0.01, name="Optimizer")
loss = CategoricalCrossentropy(name="Loss")
metrics = [CategoricalAccuracy(name="accuracy"), Precision(name="precision"), Recall(name="recall"), F1Score(average="macro", name="f1_score"), AUC(name="auc")]
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# %%
# Callbacks
model_name = f"RareSpeciesCNN_{datetime.datetime.now().strftime('%Y%m%d')}_SMOTEContrast"
callbacks = [ModelCheckpoint(f"./ModelCallbacks/checkpoint_{model_name}.keras", monitor="val_loss", save_best_only=True, verbose=0), CSVLogger(f"./ModelCallbacks/metrics_{model_name}.csv"), LearningRateScheduler(lambda epoch, lr: lr * 0.95), EarlyStopping(monitor='val_loss', patience=5, verbose=1)]

# Train model
start_time = time.time()
history = model.fit(train_DataAugmentationSMOTE_datagen, batch_size=batch_size, epochs=10, validation_data=val_datagen, callbacks=callbacks, verbose=1)
train_time = round(time.time() - start_time, 2)
print(f"\nTraining completed in \033[1m{train_time} seconds ({str(datetime.timedelta(seconds=train_time))} h)\033[0m).")

# %% [markdown]
# #### **🧪 Model Selection & 📏 Model Evaluation**

# %%
# Evaluate model
from utilities import plot_metrics
plot_metrics(history, file_path=f"./ModelsEvaluation/2_BaselineModel_TrainingValidationMetrics_{model_name}.png")

# %%
# Evaluate on validation and test sets
train_results = {'accuracy': history.history['accuracy'][-1], 'precision': history.history['precision'][-1], 'recall': history.history['recall'][-1], 'f1_score': history.history['f1_score'][-1], 'auc': history.history['auc'][-1]}
val_results = model.evaluate(val_datagen, batch_size=batch_size, return_dict=True, verbose=1)
test_results = model.evaluate(test_datagen, batch_size=batch_size, return_dict=True, verbose=1)

# Display results
from utilities import display_side_by_side, create_evaluation_dataframe
results_df = create_evaluation_dataframe(
    model_name="Baseline Model", variation="SMOTE | Grayscale=F | Contrast=T | Saturation=F | Adam=0.001",
    train_metrics=train_results, val_metrics=val_results, test_metrics=test_results, train_time=train_time,
    csv_save_path= f"./ModelsEvaluation/2_BaselineModel_TrainingValidationMetrics_{model_name}.csv"
)
display_side_by_side(results_df, super_title="Model Evaluation Results")

# %% [markdown]
# ---

# %% [markdown]
# ## **SMOTE Data Augmentation | Grayscale=F | Contrast=F | Saturation=T**

# %%
# Model - SMOTE Data Augmentation | Grayscale=F | Contrast=F | Saturation=T
model = RareSpeciesCNN(
    n_classes=n_classes,
    apply_grayscale=False,
    apply_contrast=False,
    apply_saturation=True
)

# Build the model by providing an input shape
inputs = Input(shape=(img_width, img_height, 3))        # Input shape
_ = model.call(inputs)                                  # Call the model to build it
model.summary()                                         # Print the model summary

# %%
# Compile model
optimizer = Adam(learning_rate=0.001, weight_decay=0.01, name="Optimizer")
loss = CategoricalCrossentropy(name="Loss")
metrics = [CategoricalAccuracy(name="accuracy"), Precision(name="precision"), Recall(name="recall"), F1Score(average="macro", name="f1_score"), AUC(name="auc")]
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# %%
# Callbacks
model_name = f"RareSpeciesCNN_{datetime.datetime.now().strftime('%Y%m%d')}_SMOTESaturation"
callbacks = [ModelCheckpoint(f"./ModelCallbacks/checkpoint_{model_name}.keras", monitor="val_loss", save_best_only=True, verbose=0), CSVLogger(f"./ModelCallbacks/metrics_{model_name}.csv"), LearningRateScheduler(lambda epoch, lr: lr * 0.95), EarlyStopping(monitor='val_loss', patience=5, verbose=1)]

# Train model
start_time = time.time()
history = model.fit(train_DataAugmentationSMOTE_datagen, batch_size=batch_size, epochs=10, validation_data=val_datagen, callbacks=callbacks, verbose=1)
train_time = round(time.time() - start_time, 2)
print(f"\nTraining completed in \033[1m{train_time} seconds ({str(datetime.timedelta(seconds=train_time))} h)\033[0m).")

# %% [markdown]
# #### **🧪 Model Selection & 📏 Model Evaluation**

# %%
# Evaluate model
from utilities import plot_metrics
plot_metrics(history, file_path=f"./ModelsEvaluation/2_BaselineModel_TrainingValidationMetrics_{model_name}.png")

# %%
# Evaluate on validation and test sets
train_results = {'accuracy': history.history['accuracy'][-1], 'precision': history.history['precision'][-1], 'recall': history.history['recall'][-1], 'f1_score': history.history['f1_score'][-1], 'auc': history.history['auc'][-1]}
val_results = model.evaluate(val_datagen, batch_size=batch_size, return_dict=True, verbose=1)
test_results = model.evaluate(test_datagen, batch_size=batch_size, return_dict=True, verbose=1)

# Display results
from utilities import display_side_by_side, create_evaluation_dataframe
results_df = create_evaluation_dataframe(
    model_name="Baseline Model", variation="SMOTE | Grayscale=F | Contrast=F | Saturation=T | Adam=0.001",
    train_metrics=train_results, val_metrics=val_results, test_metrics=test_results, train_time=train_time
)
display_side_by_side(results_df, super_title="Model Evaluation Results")
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 18s 971ms/step - accuracy: 0.2122 - auc: 0.8351 - f1_score: 0.0360 - loss: 4.0163 - precision: 0.8467 - recall: 0.0143
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 17s 908ms/step - accuracy: 0.1962 - auc: 0.8396 - f1_score: 0.0328 - loss: 4.0116 - precision: 0.9088 - recall: 0.0195
# <h1 style="text-align: left; margin-bottom: -15px;">Model Evaluation Results</h1><br><div style="display: flex;"><div style="margin-right: 20px;"><h3 style="text-align: center;color:#555555;"></h3><table style="display:inline; margin-right: 20px;" border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th colspan="5" halign="left">Train</th>
#       <th colspan="5" halign="left">Validation</th>
#       <th colspan="5" halign="left">Test</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>Time of Execution</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1 Score</th>
#       <th>AUROC</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1 Score</th>
#       <th>AUROC</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1 Score</th>
#       <th>AUROC</th>
#     </tr>
#     <tr>
#       <th>Model</th>
#       <th>Variation</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Baseline Model</th>
#       <th>SMOTE | Grayscale=F | Contrast=F | Saturation=T | Adam=0.001</th>
#       <td>1809.01</td>
#       <td>0.1433</td>
#       <td>0.7314</td>
#       <td>0.0216</td>
#       <td>0.054</td>
#       <td>0.8337</td>
#       <td>0.1628</td>
#       <td>0.8261</td>
#       <td>0.0159</td>
#       <td>0.0563</td>
#       <td>0.8264</td>
#       <td>0.156</td>
#       <td>0.9048</td>
#       <td>0.0158</td>
#       <td>0.0512</td>
#       <td>0.8272</td>
#     </tr>
#   </tbody>
# </table style="display:inline; margin-right: 20px;"></div></div>

# %% [markdown]
# ---

# %% [markdown]
# # **🏋️ Weights**

# %%
# Count Samples in Each Class in the Original Training Set
original_class_counts = {}
total_samples = 0
for class_name in class_names:
    class_path = train_dir / class_name
    if class_path.is_dir():
        count = len(list(class_path.glob('*'))) # Count image files
        original_class_counts[class_name] = count
        total_samples += count
    else:
        print(f"Warning: Expected directory not found: {class_path}")

# Calculate Class Weights
# Formula: weight_for_class_i = (total_samples / (num_classes * samples_in_class_i))  -> This gives higher weight to smaller classes.
class_weights = {}
for class_name, count in original_class_counts.items():
    if count == 0:
        print(f"Warning: Class '{class_name}' has 0 samples. Assigning weight 0.")
        weight = 0.0
    else:
        weight = (total_samples) / (len(class_names) * count)

    # Get the index for this class name
    class_index = class_indices[class_name]
    class_weights[class_index] = weight

# %% [markdown]
# ## **Weights | Grayscale=F | Contrast=F | Saturation=F**

# %%
# Model - Weights | Grayscale=F | Contrast=F | Saturation=F
model = RareSpeciesCNN(
    n_classes=n_classes,
    apply_grayscale=False,
    apply_contrast=False,
    apply_saturation=False
)

# Build the model by providing an input shape
inputs = Input(shape=(img_width, img_height, 3))        # Input shape
_ = model.call(inputs)                                  # Call the model to build it
model.summary()                                         # Print the model summary
# Out:
# Model: "rare_species_cnn_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Rescale_Layer (Rescaling)       │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block1_Conv (Conv2D)       │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block1_BN                  │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block1_Act (Activation)    │ (None, 224, 224, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block1_Pool (MaxPooling2D) │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block2_Conv (Conv2D)       │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block2_BN                  │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block2_Act (Activation)    │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block2_Pool (MaxPooling2D) │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block3_Conv (Conv2D)       │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block3_BN                  │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block3_Act (Activation)    │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block3_Pool (MaxPooling2D) │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block4_Conv (Conv2D)       │ (None, 28, 28, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block4_BN                  │ (None, 28, 28, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block4_Act (Activation)    │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block4_Pool (MaxPooling2D) │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Global_Average_Pooling          │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dense_Layer1 (Dense)            │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dense_Layer1_BN                 │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dense_Layer1_Act (Activation)   │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dropout_Layer (Dropout)         │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output_Layer (Dense)            │ (None, 202)            │        26,058 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 449,802 (1.72 MB)
#  Trainable params: 448,586 (1.71 MB)
#  Non-trainable params: 1,216 (4.75 KB)

# %%
# Compile model
optimizer = Adam(learning_rate=0.001, weight_decay=0.01, name="Optimizer")
loss = CategoricalCrossentropy(name="Loss")
metrics = [CategoricalAccuracy(name="accuracy"), Precision(name="precision"), Recall(name="recall"), F1Score(average="macro", name="f1_score"), AUC(name="auc")]
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# %%
# Callbacks
model_name = f"RareSpeciesCNN_{datetime.datetime.now().strftime('%Y%m%d')}_Weights"
callbacks = [ModelCheckpoint(f"./ModelCallbacks/checkpoint_{model_name}.keras", monitor="val_loss", save_best_only=True, verbose=0), CSVLogger(f"./ModelCallbacks/metrics_{model_name}.csv"), LearningRateScheduler(lambda epoch, lr: lr * 0.95), EarlyStopping(monitor='val_loss', patience=5, verbose=1)]

# Train model
start_time = time.time()
history = model.fit(train_datagen, batch_size=batch_size, epochs=10, validation_data=val_datagen, callbacks=callbacks, verbose=1,
                    class_weight=class_weights) # Pass class weights to the fit method
train_time = round(time.time() - start_time, 2)
print(f"\nTraining completed in \033[1m{train_time} seconds ({str(datetime.timedelta(seconds=train_time))} h)\033[0m).")
# Out:
# Epoch 1/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 190s 1s/step - accuracy: 0.0113 - auc: 0.5612 - f1_score: 0.0060 - loss: 5.7558 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.0033 - val_auc: 0.5253 - val_f1_score: 5.2188e-04 - val_loss: 5.6732 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 9.5000e-04
# Epoch 2/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 160s 1s/step - accuracy: 0.0305 - auc: 0.6648 - f1_score: 0.0182 - loss: 5.2714 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.0150 - val_auc: 0.5624 - val_f1_score: 0.0048 - val_loss: 5.5619 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 9.0250e-04
# Epoch 3/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 198s 1s/step - accuracy: 0.0319 - auc: 0.6948 - f1_score: 0.0200 - loss: 5.0750 - precision: 0.0433 - recall: 3.8196e-05 - val_accuracy: 0.0259 - val_auc: 0.6468 - val_f1_score: 0.0081 - val_loss: 5.2542 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 8.5737e-04
# Epoch 4/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 205s 1s/step - accuracy: 0.0422 - auc: 0.7129 - f1_score: 0.0231 - loss: 4.9400 - precision: 0.0942 - recall: 4.7688e-05 - val_accuracy: 0.0551 - val_auc: 0.7338 - val_f1_score: 0.0282 - val_loss: 4.9066 - val_precision: 1.0000 - val_recall: 8.3472e-04 - learning_rate: 8.1451e-04
# Epoch 5/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 164s 1s/step - accuracy: 0.0462 - auc: 0.7316 - f1_score: 0.0280 - loss: 4.8253 - precision: 0.2815 - recall: 3.0015e-04 - val_accuracy: 0.0426 - val_auc: 0.7312 - val_f1_score: 0.0248 - val_loss: 4.8980 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 7.7378e-04
# Epoch 6/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 165s 1s/step - accuracy: 0.0498 - auc: 0.7466 - f1_score: 0.0308 - loss: 4.7314 - precision: 0.4184 - recall: 0.0010 - val_accuracy: 0.0609 - val_auc: 0.7523 - val_f1_score: 0.0355 - val_loss: 4.8245 - val_precision: 1.0000 - val_recall: 8.3472e-04 - learning_rate: 7.3509e-04
# Epoch 7/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 191s 1s/step - accuracy: 0.0624 - auc: 0.7580 - f1_score: 0.0383 - loss: 4.6401 - precision: 0.6823 - recall: 7.9460e-04 - val_accuracy: 0.0584 - val_auc: 0.7504 - val_f1_score: 0.0404 - val_loss: 4.7546 - val_precision: 0.3333 - val_recall: 8.3472e-04 - learning_rate: 6.9834e-04
# Epoch 8/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 159s 1s/step - accuracy: 0.0631 - auc: 0.7635 - f1_score: 0.0411 - loss: 4.5842 - precision: 0.4427 - recall: 0.0019 - val_accuracy: 0.0868 - val_auc: 0.7698 - val_f1_score: 0.0536 - val_loss: 4.6289 - val_precision: 1.0000 - val_recall: 8.3472e-04 - learning_rate: 6.6342e-04
# Epoch 9/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 205s 1s/step - accuracy: 0.0681 - auc: 0.7759 - f1_score: 0.0448 - loss: 4.4946 - precision: 0.3784 - recall: 0.0023 - val_accuracy: 0.0451 - val_auc: 0.7183 - val_f1_score: 0.0304 - val_loss: 4.9535 - val_precision: 0.8000 - val_recall: 0.0033 - learning_rate: 6.3025e-04
# Epoch 10/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 206s 1s/step - accuracy: 0.0800 - auc: 0.7827 - f1_score: 0.0520 - loss: 4.4489 - precision: 0.5221 - recall: 0.0039 - val_accuracy: 0.0935 - val_auc: 0.7747 - val_f1_score: 0.0629 - val_loss: 4.5998 - val_precision: 0.8889 - val_recall: 0.0067 - learning_rate: 5.9874e-04
#
# Training completed in 1879.22 seconds (0:31:19.220000 h)).

# %% [markdown]
# #### **🧪 Model Selection & 📏 Model Evaluation**

# %%
# Evaluate model
from utilities import plot_metrics
plot_metrics(history, file_path=f"./ModelsEvaluation/2_BaselineModel_TrainingValidationMetrics_{model_name}.png")

# %%
# Evaluate on validation and test sets
train_results = {'accuracy': history.history['accuracy'][-1], 'precision': history.history['precision'][-1], 'recall': history.history['recall'][-1], 'f1_score': history.history['f1_score'][-1], 'auc': history.history['auc'][-1]}
val_results = model.evaluate(val_datagen, batch_size=batch_size, return_dict=True, verbose=1)
test_results = model.evaluate(test_datagen, batch_size=batch_size, return_dict=True, verbose=1)

# Display results
from utilities import display_side_by_side, create_evaluation_dataframe
results_df = create_evaluation_dataframe(
    model_name="Baseline Model", variation="Weights | Grayscale=F | Contrast=F | Saturation=F | Adam=0.001",
    train_metrics=train_results, val_metrics=val_results, test_metrics=test_results, train_time=train_time
)
display_side_by_side(results_df, super_title="Model Evaluation Results")
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 17s 908ms/step - accuracy: 0.1199 - auc: 0.7815 - f1_score: 0.0357 - loss: 4.5636 - precision: 0.8239 - recall: 0.0042
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 19s 996ms/step - accuracy: 0.1041 - auc: 0.7780 - f1_score: 0.0333 - loss: 4.5723 - precision: 0.3925 - recall: 0.0022
# <h1 style="text-align: left; margin-bottom: -15px;">Model Evaluation Results</h1><br><div style="display: flex;"><div style="margin-right: 20px;"><h3 style="text-align: center;color:#555555;"></h3><table style="display:inline; margin-right: 20px;" border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th colspan="5" halign="left">Train</th>
#       <th colspan="5" halign="left">Validation</th>
#       <th colspan="5" halign="left">Test</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>Time of Execution</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1 Score</th>
#       <th>AUROC</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1 Score</th>
#       <th>AUROC</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1 Score</th>
#       <th>AUROC</th>
#     </tr>
#     <tr>
#       <th>Model</th>
#       <th>Variation</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Baseline Model</th>
#       <th>Weights | Grayscale=F | Contrast=F | Saturation=F | Adam=0.001</th>
#       <td>1879.22</td>
#       <td>0.0799</td>
#       <td>0.5</td>
#       <td>0.0035</td>
#       <td>0.0553</td>
#       <td>0.7856</td>
#       <td>0.0935</td>
#       <td>0.8889</td>
#       <td>0.0067</td>
#       <td>0.0629</td>
#       <td>0.7747</td>
#       <td>0.0842</td>
#       <td>0.6667</td>
#       <td>0.0033</td>
#       <td>0.0574</td>
#       <td>0.7635</td>
#     </tr>
#   </tbody>
# </table style="display:inline; margin-right: 20px;"></div></div>

# %% [markdown]
# ---

# %% [markdown]
# ## **Weights | Grayscale=T | Contrast=F | Saturation=F**

# %%
# Model - Weights | Grayscale=T | Contrast=F | Saturation=F
model = RareSpeciesCNN(
    n_classes=n_classes,
    apply_grayscale=True,
    apply_contrast=False,
    apply_saturation=False
)

# Build the model by providing an input shape
inputs = Input(shape=(img_width, img_height, 3))        # Input shape
_ = model.call(inputs)                                  # Call the model to build it
model.summary()                                         # Print the model summary
# Out:
# Model: "rare_species_cnn_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Rescale_Layer (Rescaling)       │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ RGB_to_Grayscale (Lambda)       │ (None, 224, 224, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block1_Conv (Conv2D)       │ (None, 224, 224, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block1_BN                  │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block1_Act (Activation)    │ (None, 224, 224, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block1_Pool (MaxPooling2D) │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block2_Conv (Conv2D)       │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block2_BN                  │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block2_Act (Activation)    │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block2_Pool (MaxPooling2D) │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block3_Conv (Conv2D)       │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block3_BN                  │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block3_Act (Activation)    │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block3_Pool (MaxPooling2D) │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block4_Conv (Conv2D)       │ (None, 28, 28, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block4_BN                  │ (None, 28, 28, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block4_Act (Activation)    │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block4_Pool (MaxPooling2D) │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Global_Average_Pooling          │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dense_Layer1 (Dense)            │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dense_Layer1_BN                 │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dense_Layer1_Act (Activation)   │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dropout_Layer (Dropout)         │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output_Layer (Dense)            │ (None, 202)            │        26,058 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 449,226 (1.71 MB)
#  Trainable params: 448,010 (1.71 MB)
#  Non-trainable params: 1,216 (4.75 KB)

# %%
# Compile model
optimizer = Adam(learning_rate=0.001, weight_decay=0.01, name="Optimizer")
loss = CategoricalCrossentropy(name="Loss")
metrics = [CategoricalAccuracy(name="accuracy"), Precision(name="precision"), Recall(name="recall"), F1Score(average="macro", name="f1_score"), AUC(name="auc")]
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# %%
# Callbacks
model_name = f"RareSpeciesCNN_{datetime.datetime.now().strftime('%Y%m%d')}_WeightsGrayscale"
callbacks = [ModelCheckpoint(f"./ModelCallbacks/checkpoint_{model_name}.keras", monitor="val_loss", save_best_only=True, verbose=0), CSVLogger(f"./ModelCallbacks/metrics_{model_name}.csv"), LearningRateScheduler(lambda epoch, lr: lr * 0.95), EarlyStopping(monitor='val_loss', patience=5, verbose=1)]

# Train model
start_time = time.time()
history = model.fit(train_datagen, batch_size=batch_size, epochs=10, validation_data=val_datagen, callbacks=callbacks, verbose=1, class_weight=class_weights)
train_time = round(time.time() - start_time, 2)
print(f"\nTraining completed in \033[1m{train_time} seconds ({str(datetime.timedelta(seconds=train_time))} h)\033[0m).")
# Out:
# Epoch 1/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 173s 1s/step - accuracy: 0.0085 - auc: 0.5470 - f1_score: 0.0051 - loss: 5.7928 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.0033 - val_auc: 0.4950 - val_f1_score: 9.7178e-05 - val_loss: 5.7229 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 9.5000e-04
# Epoch 2/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 195s 1s/step - accuracy: 0.0180 - auc: 0.6231 - f1_score: 0.0102 - loss: 5.3939 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.0058 - val_auc: 0.5044 - val_f1_score: 4.1165e-04 - val_loss: 5.8861 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 9.0250e-04
# Epoch 3/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 163s 1s/step - accuracy: 0.0194 - auc: 0.6477 - f1_score: 0.0107 - loss: 5.2124 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.0058 - val_auc: 0.5345 - val_f1_score: 3.9584e-04 - val_loss: 5.7582 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 8.5737e-04
# Epoch 4/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 161s 1s/step - accuracy: 0.0277 - auc: 0.6716 - f1_score: 0.0161 - loss: 5.0768 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.0100 - val_auc: 0.6073 - val_f1_score: 0.0035 - val_loss: 5.3972 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 8.1451e-04
# Epoch 5/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 206s 1s/step - accuracy: 0.0328 - auc: 0.6847 - f1_score: 0.0189 - loss: 5.0026 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.0117 - val_auc: 0.6254 - val_f1_score: 0.0032 - val_loss: 5.3453 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 7.7378e-04
# Epoch 6/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 197s 1s/step - accuracy: 0.0355 - auc: 0.7038 - f1_score: 0.0193 - loss: 4.9008 - precision: 0.1689 - recall: 6.9367e-05 - val_accuracy: 0.0409 - val_auc: 0.7067 - val_f1_score: 0.0312 - val_loss: 4.9906 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 7.3509e-04
# Epoch 7/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 198s 1s/step - accuracy: 0.0444 - auc: 0.7150 - f1_score: 0.0262 - loss: 4.8446 - precision: 0.2699 - recall: 3.9202e-04 - val_accuracy: 0.0275 - val_auc: 0.7054 - val_f1_score: 0.0163 - val_loss: 4.9691 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 6.9834e-04
# Epoch 8/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 208s 1s/step - accuracy: 0.0446 - auc: 0.7224 - f1_score: 0.0276 - loss: 4.7829 - precision: 0.2859 - recall: 6.4437e-04 - val_accuracy: 0.0342 - val_auc: 0.7014 - val_f1_score: 0.0234 - val_loss: 4.9778 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 6.6342e-04
# Epoch 9/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 165s 1s/step - accuracy: 0.0463 - auc: 0.7349 - f1_score: 0.0285 - loss: 4.7072 - precision: 0.2143 - recall: 3.6966e-04 - val_accuracy: 0.0376 - val_auc: 0.6887 - val_f1_score: 0.0233 - val_loss: 5.0287 - val_precision: 0.8000 - val_recall: 0.0033 - learning_rate: 6.3025e-04
# Epoch 10/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 203s 1s/step - accuracy: 0.0575 - auc: 0.7405 - f1_score: 0.0358 - loss: 4.6776 - precision: 0.4411 - recall: 6.8909e-04 - val_accuracy: 0.0568 - val_auc: 0.7327 - val_f1_score: 0.0365 - val_loss: 4.8490 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 5.9874e-04
#
# Training completed in 1869.01 seconds (0:31:09.010000 h)).

# %% [markdown]
# #### **🧪 Model Selection & 📏 Model Evaluation**

# %%
# Evaluate model
from utilities import plot_metrics
plot_metrics(history, file_path=f"./ModelsEvaluation/2_BaselineModel_TrainingValidationMetrics_{model_name}.png")

# %%
# Evaluate on validation and test sets
train_results = {'accuracy': history.history['accuracy'][-1], 'precision': history.history['precision'][-1], 'recall': history.history['recall'][-1], 'f1_score': history.history['f1_score'][-1], 'auc': history.history['auc'][-1]}
val_results = model.evaluate(val_datagen, batch_size=batch_size, return_dict=True, verbose=1)
test_results = model.evaluate(test_datagen, batch_size=batch_size, return_dict=True, verbose=1)

# Display results
from utilities import display_side_by_side, create_evaluation_dataframe
results_df = create_evaluation_dataframe(
    model_name="Baseline Model", variation="Weights | Grayscale=T | Contrast=F | Saturation=F | Adam=0.001",
    train_metrics=train_results, val_metrics=val_results, test_metrics=test_results, train_time=train_time
)
display_side_by_side(results_df, super_title="Model Evaluation Results")
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 17s 925ms/step - accuracy: 0.0840 - auc: 0.7334 - f1_score: 0.0207 - loss: 4.8187 - precision: 0.0000e+00 - recall: 0.0000e+00
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 18s 942ms/step - accuracy: 0.0732 - auc: 0.7350 - f1_score: 0.0164 - loss: 4.8065 - precision: 0.2750 - recall: 6.0382e-04
# <h1 style="text-align: left; margin-bottom: -15px;">Model Evaluation Results</h1><br><div style="display: flex;"><div style="margin-right: 20px;"><h3 style="text-align: center;color:#555555;"></h3><table style="display:inline; margin-right: 20px;" border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th colspan="5" halign="left">Train</th>
#       <th colspan="5" halign="left">Validation</th>
#       <th colspan="5" halign="left">Test</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>Time of Execution</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1 Score</th>
#       <th>AUROC</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1 Score</th>
#       <th>AUROC</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1 Score</th>
#       <th>AUROC</th>
#     </tr>
#     <tr>
#       <th>Model</th>
#       <th>Variation</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Baseline Model</th>
#       <th>Weights | Grayscale=T | Contrast=F | Saturation=F | Adam=0.001</th>
#       <td>1869.01</td>
#       <td>0.0552</td>
#       <td>0.4286</td>
#       <td>0.0009</td>
#       <td>0.0344</td>
#       <td>0.74</td>
#       <td>0.0568</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0365</td>
#       <td>0.7327</td>
#       <td>0.05</td>
#       <td>0.5</td>
#       <td>0.0008</td>
#       <td>0.0258</td>
#       <td>0.7271</td>
#     </tr>
#   </tbody>
# </table style="display:inline; margin-right: 20px;"></div></div>

# %% [markdown]
# ---

# %% [markdown]
# ## **Weights | Grayscale=F | Contrast=T | Saturation=F**

# %%
# Model - Weights | Grayscale=F | Contrast=T | Saturation=F
model = RareSpeciesCNN(
    n_classes=n_classes,
    apply_grayscale=False,
    apply_contrast=True,
    apply_saturation=False
)

# Build the model by providing an input shape
inputs = Input(shape=(img_width, img_height, 3))        # Input shape
_ = model.call(inputs)                                  # Call the model to build it
model.summary()                                         # Print the model summary
# Out:
# Model: "rare_species_cnn_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Rescale_Layer (Rescaling)       │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Adjust_Contrast (Lambda)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block1_Conv (Conv2D)       │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block1_BN                  │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block1_Act (Activation)    │ (None, 224, 224, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block1_Pool (MaxPooling2D) │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block2_Conv (Conv2D)       │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block2_BN                  │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block2_Act (Activation)    │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block2_Pool (MaxPooling2D) │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block3_Conv (Conv2D)       │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block3_BN                  │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block3_Act (Activation)    │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block3_Pool (MaxPooling2D) │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block4_Conv (Conv2D)       │ (None, 28, 28, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block4_BN                  │ (None, 28, 28, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block4_Act (Activation)    │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block4_Pool (MaxPooling2D) │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Global_Average_Pooling          │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dense_Layer1 (Dense)            │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dense_Layer1_BN                 │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dense_Layer1_Act (Activation)   │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dropout_Layer (Dropout)         │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output_Layer (Dense)            │ (None, 202)            │        26,058 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 449,802 (1.72 MB)
#  Trainable params: 448,586 (1.71 MB)
#  Non-trainable params: 1,216 (4.75 KB)

# %%
# Compile model
optimizer = Adam(learning_rate=0.001, weight_decay=0.01, name="Optimizer")
loss = CategoricalCrossentropy(name="Loss")
metrics = [CategoricalAccuracy(name="accuracy"), Precision(name="precision"), Recall(name="recall"), F1Score(average="macro", name="f1_score"), AUC(name="auc")]
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# %%
# Callbacks
model_name = f"RareSpeciesCNN_{datetime.datetime.now().strftime('%Y%m%d')}_WeightsContrast"
callbacks = [ModelCheckpoint(f"./ModelCallbacks/checkpoint_{model_name}.keras", monitor="val_loss", save_best_only=True, verbose=0), CSVLogger(f"./ModelCallbacks/metrics_{model_name}.csv"), LearningRateScheduler(lambda epoch, lr: lr * 0.95), EarlyStopping(monitor='val_loss', patience=5, verbose=1)]

# Train model
start_time = time.time()
history = model.fit(train_datagen, batch_size=batch_size, epochs=10, validation_data=val_datagen, callbacks=callbacks, verbose=1,
                    class_weight=class_weights)    # Pass class weights to the fit method
train_time = round(time.time() - start_time, 2)
print(f"\nTraining completed in \033[1m{train_time} seconds ({str(datetime.timedelta(seconds=train_time))} h)\033[0m).")
# Out:
# Epoch 1/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 179s 1s/step - accuracy: 0.0111 - auc: 0.5633 - f1_score: 0.0056 - loss: 5.7470 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.0058 - val_auc: 0.5342 - val_f1_score: 3.4607e-04 - val_loss: 5.7062 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 9.5000e-04
# Epoch 2/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 158s 1s/step - accuracy: 0.0204 - auc: 0.6490 - f1_score: 0.0124 - loss: 5.3290 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.0275 - val_auc: 0.6148 - val_f1_score: 0.0046 - val_loss: 5.4002 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 9.0250e-04
# Epoch 3/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 158s 1s/step - accuracy: 0.0324 - auc: 0.6880 - f1_score: 0.0170 - loss: 5.0711 - precision: 0.0183 - recall: 1.2322e-05 - val_accuracy: 0.0317 - val_auc: 0.6612 - val_f1_score: 0.0123 - val_loss: 5.2029 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 8.5737e-04
# Epoch 4/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 205s 1s/step - accuracy: 0.0443 - auc: 0.7201 - f1_score: 0.0270 - loss: 4.9053 - precision: 0.0552 - recall: 6.1335e-05 - val_accuracy: 0.0559 - val_auc: 0.7143 - val_f1_score: 0.0255 - val_loss: 4.9940 - val_precision: 1.0000 - val_recall: 8.3472e-04 - learning_rate: 8.1451e-04
# Epoch 5/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 162s 1s/step - accuracy: 0.0566 - auc: 0.7389 - f1_score: 0.0327 - loss: 4.7587 - precision: 0.3481 - recall: 7.2708e-04 - val_accuracy: 0.0618 - val_auc: 0.7375 - val_f1_score: 0.0299 - val_loss: 4.8580 - val_precision: 0.4286 - val_recall: 0.0025 - learning_rate: 7.7378e-04
# Epoch 6/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 204s 1s/step - accuracy: 0.0584 - auc: 0.7523 - f1_score: 0.0366 - loss: 4.6853 - precision: 0.4399 - recall: 0.0011 - val_accuracy: 0.0718 - val_auc: 0.7584 - val_f1_score: 0.0413 - val_loss: 4.7321 - val_precision: 0.6000 - val_recall: 0.0025 - learning_rate: 7.3509e-04
# Epoch 7/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 191s 1s/step - accuracy: 0.0677 - auc: 0.7705 - f1_score: 0.0442 - loss: 4.5570 - precision: 0.5318 - recall: 0.0019 - val_accuracy: 0.0651 - val_auc: 0.7506 - val_f1_score: 0.0406 - val_loss: 4.7326 - val_precision: 1.0000 - val_recall: 0.0017 - learning_rate: 6.9834e-04
# Epoch 8/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 157s 1s/step - accuracy: 0.0715 - auc: 0.7774 - f1_score: 0.0447 - loss: 4.5025 - precision: 0.4990 - recall: 0.0032 - val_accuracy: 0.0952 - val_auc: 0.7824 - val_f1_score: 0.0598 - val_loss: 4.5417 - val_precision: 0.7500 - val_recall: 0.0075 - learning_rate: 6.6342e-04
# Epoch 9/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 163s 1s/step - accuracy: 0.0777 - auc: 0.7859 - f1_score: 0.0502 - loss: 4.4710 - precision: 0.4807 - recall: 0.0026 - val_accuracy: 0.0893 - val_auc: 0.7931 - val_f1_score: 0.0603 - val_loss: 4.5281 - val_precision: 0.6000 - val_recall: 0.0025 - learning_rate: 6.3025e-04
# Epoch 10/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 164s 1s/step - accuracy: 0.0843 - auc: 0.7957 - f1_score: 0.0572 - loss: 4.3753 - precision: 0.4369 - recall: 0.0035 - val_accuracy: 0.1043 - val_auc: 0.7868 - val_f1_score: 0.0650 - val_loss: 4.5287 - val_precision: 0.5000 - val_recall: 0.0025 - learning_rate: 5.9874e-04
#
# Training completed in 1778.76 seconds (0:29:38.760000 h)).

# %% [markdown]
# #### **🧪 Model Selection & 📏 Model Evaluation**

# %%
# Evaluate model
from utilities import plot_metrics
plot_metrics(history, file_path=f"./ModelsEvaluation/2_BaselineModel_TrainingValidationMetrics_{model_name}.png")

# %%
# Evaluate on validation and test sets
train_results = {'accuracy': history.history['accuracy'][-1], 'precision': history.history['precision'][-1], 'recall': history.history['recall'][-1], 'f1_score': history.history['f1_score'][-1], 'auc': history.history['auc'][-1]}
val_results = model.evaluate(val_datagen, batch_size=batch_size, return_dict=True, verbose=1)
test_results = model.evaluate(test_datagen, batch_size=batch_size, return_dict=True, verbose=1)

# Display results
from utilities import display_side_by_side, create_evaluation_dataframe
results_df = create_evaluation_dataframe(
    model_name="Baseline Model", variation="Weights | Grayscale=F | Contrast=T | Saturation=F | Adam=0.001",
    train_metrics=train_results, val_metrics=val_results, test_metrics=test_results, train_time=train_time
)
display_side_by_side(results_df, super_title="Model Evaluation Results")
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 17s 907ms/step - accuracy: 0.1393 - auc: 0.7955 - f1_score: 0.0351 - loss: 4.4391 - precision: 0.3250 - recall: 0.0018
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 19s 998ms/step - accuracy: 0.1112 - auc: 0.8087 - f1_score: 0.0278 - loss: 4.4104 - precision: 0.9500 - recall: 0.0038
# <h1 style="text-align: left; margin-bottom: -15px;">Model Evaluation Results</h1><br><div style="display: flex;"><div style="margin-right: 20px;"><h3 style="text-align: center;color:#555555;"></h3><table style="display:inline; margin-right: 20px;" border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th colspan="5" halign="left">Train</th>
#       <th colspan="5" halign="left">Validation</th>
#       <th colspan="5" halign="left">Test</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>Time of Execution</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1 Score</th>
#       <th>AUROC</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1 Score</th>
#       <th>AUROC</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1 Score</th>
#       <th>AUROC</th>
#     </tr>
#     <tr>
#       <th>Model</th>
#       <th>Variation</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Baseline Model</th>
#       <th>Weights | Grayscale=F | Contrast=T | Saturation=F | Adam=0.001</th>
#       <td>1778.76</td>
#       <td>0.0847</td>
#       <td>0.4658</td>
#       <td>0.0035</td>
#       <td>0.0601</td>
#       <td>0.7944</td>
#       <td>0.1043</td>
#       <td>0.5</td>
#       <td>0.0025</td>
#       <td>0.065</td>
#       <td>0.7868</td>
#       <td>0.0834</td>
#       <td>1.0</td>
#       <td>0.0033</td>
#       <td>0.0512</td>
#       <td>0.7906</td>
#     </tr>
#   </tbody>
# </table style="display:inline; margin-right: 20px;"></div></div>

# %% [markdown]
# ---

# %% [markdown]
# ## **Weights | Grayscale=F | Contrast=F | Saturation=T**

# %%
# Model - Weights | Grayscale=F | Contrast=F | Saturation=T
model = RareSpeciesCNN(
    n_classes=n_classes,
    apply_grayscale=False,
    apply_contrast=False,
    apply_saturation=True
)

# Build the model by providing an input shape
inputs = Input(shape=(img_width, img_height, 3))        # Input shape
_ = model.call(inputs)                                  # Call the model to build it
model.summary()                                         # Print the model summary
# Out:
# Model: "rare_species_cnn_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Rescale_Layer (Rescaling)       │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Adjust_Saturation (Lambda)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block1_Conv (Conv2D)       │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block1_BN                  │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block1_Act (Activation)    │ (None, 224, 224, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block1_Pool (MaxPooling2D) │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block2_Conv (Conv2D)       │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block2_BN                  │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block2_Act (Activation)    │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block2_Pool (MaxPooling2D) │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block3_Conv (Conv2D)       │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block3_BN                  │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block3_Act (Activation)    │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block3_Pool (MaxPooling2D) │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block4_Conv (Conv2D)       │ (None, 28, 28, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block4_BN                  │ (None, 28, 28, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block4_Act (Activation)    │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv_Block4_Pool (MaxPooling2D) │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Global_Average_Pooling          │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dense_Layer1 (Dense)            │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dense_Layer1_BN                 │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dense_Layer1_Act (Activation)   │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dropout_Layer (Dropout)         │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output_Layer (Dense)            │ (None, 202)            │        26,058 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 449,802 (1.72 MB)
#  Trainable params: 448,586 (1.71 MB)
#  Non-trainable params: 1,216 (4.75 KB)

# %%
# Compile model
optimizer = Adam(learning_rate=0.001, weight_decay=0.01, name="Optimizer")
loss = CategoricalCrossentropy(name="Loss")
metrics = [CategoricalAccuracy(name="accuracy"), Precision(name="precision"), Recall(name="recall"), F1Score(average="macro", name="f1_score"), AUC(name="auc")]
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# %%
# Callbacks
model_name = f"RareSpeciesCNN_{datetime.datetime.now().strftime('%Y%m%d')}_WeightsSaturation"
callbacks = [ModelCheckpoint(f"./ModelCallbacks/checkpoint_{model_name}.keras", monitor="val_loss", save_best_only=True, verbose=0), CSVLogger(f"./ModelCallbacks/metrics_{model_name}.csv"), LearningRateScheduler(lambda epoch, lr: lr * 0.95), EarlyStopping(monitor='val_loss', patience=5, verbose=1)]

# Train model
start_time = time.time()
history = model.fit(train_datagen, batch_size=batch_size, epochs=10, validation_data=val_datagen, callbacks=callbacks, verbose=1,
                    class_weight=class_weights)     # Pass class weights to the fit method
train_time = round(time.time() - start_time, 2)
print(f"\nTraining completed in \033[1m{train_time} seconds ({str(datetime.timedelta(seconds=train_time))} h)\033[0m).")
# Out:
# Epoch 1/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 178s 1s/step - accuracy: 0.0138 - auc: 0.5721 - f1_score: 0.0067 - loss: 5.7472 - precision: 0.0253 - recall: 2.8081e-05 - val_accuracy: 0.0050 - val_auc: 0.5272 - val_f1_score: 5.2110e-05 - val_loss: 5.6181 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 9.5000e-04
# Epoch 2/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 156s 1s/step - accuracy: 0.0244 - auc: 0.6667 - f1_score: 0.0144 - loss: 5.2837 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.0075 - val_auc: 0.5550 - val_f1_score: 0.0016 - val_loss: 5.6617 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 9.0250e-04
# Epoch 3/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 210s 1s/step - accuracy: 0.0377 - auc: 0.6914 - f1_score: 0.0217 - loss: 5.0709 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.0492 - val_auc: 0.6781 - val_f1_score: 0.0216 - val_loss: 5.1279 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 8.5737e-04
# Epoch 4/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 156s 1s/step - accuracy: 0.0405 - auc: 0.7165 - f1_score: 0.0234 - loss: 4.9541 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.0476 - val_auc: 0.7132 - val_f1_score: 0.0259 - val_loss: 4.9799 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 8.1451e-04
# Epoch 5/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 158s 1s/step - accuracy: 0.0524 - auc: 0.7337 - f1_score: 0.0306 - loss: 4.8139 - precision: 0.4178 - recall: 6.7716e-04 - val_accuracy: 0.0651 - val_auc: 0.7503 - val_f1_score: 0.0423 - val_loss: 4.7965 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 7.7378e-04
# Epoch 6/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 154s 1s/step - accuracy: 0.0527 - auc: 0.7492 - f1_score: 0.0327 - loss: 4.7285 - precision: 0.2490 - recall: 2.4279e-04 - val_accuracy: 0.0643 - val_auc: 0.7491 - val_f1_score: 0.0460 - val_loss: 4.8189 - val_precision: 1.0000 - val_recall: 8.3472e-04 - learning_rate: 7.3509e-04
# Epoch 7/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 206s 1s/step - accuracy: 0.0618 - auc: 0.7648 - f1_score: 0.0406 - loss: 4.6321 - precision: 0.6617 - recall: 0.0011 - val_accuracy: 0.0693 - val_auc: 0.7450 - val_f1_score: 0.0356 - val_loss: 4.7686 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 6.9834e-04
# Epoch 8/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 197s 1s/step - accuracy: 0.0714 - auc: 0.7713 - f1_score: 0.0440 - loss: 4.5761 - precision: 0.2374 - recall: 0.0011 - val_accuracy: 0.0943 - val_auc: 0.7796 - val_f1_score: 0.0560 - val_loss: 4.6118 - val_precision: 0.5000 - val_recall: 8.3472e-04 - learning_rate: 6.6342e-04
# Epoch 9/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 204s 1s/step - accuracy: 0.0778 - auc: 0.7811 - f1_score: 0.0492 - loss: 4.4903 - precision: 0.2941 - recall: 0.0018 - val_accuracy: 0.0735 - val_auc: 0.7699 - val_f1_score: 0.0508 - val_loss: 4.6632 - val_precision: 1.0000 - val_recall: 8.3472e-04 - learning_rate: 6.3025e-04
# Epoch 10/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 204s 1s/step - accuracy: 0.0788 - auc: 0.7892 - f1_score: 0.0507 - loss: 4.4325 - precision: 0.4363 - recall: 0.0021 - val_accuracy: 0.0801 - val_auc: 0.7574 - val_f1_score: 0.0618 - val_loss: 4.7070 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 5.9874e-04
#
# Training completed in 1822.11 seconds (0:30:22.110000 h)).

# %% [markdown]
# #### **🧪 Model Selection & 📏 Model Evaluation**

# %%
# Evaluate model
from utilities import plot_metrics
plot_metrics(history, file_path=f"./ModelsEvaluation/2_BaselineModel_TrainingValidationMetrics_{model_name}.png")

# %%
# Evaluate on validation and test sets
train_results = {'accuracy': history.history['accuracy'][-1], 'precision': history.history['precision'][-1], 'recall': history.history['recall'][-1], 'f1_score': history.history['f1_score'][-1], 'auc': history.history['auc'][-1]}
val_results = model.evaluate(val_datagen, batch_size=batch_size, return_dict=True, verbose=1)
test_results = model.evaluate(test_datagen, batch_size=batch_size, return_dict=True, verbose=1)

# Display results
from utilities import display_side_by_side, create_evaluation_dataframe
results_df = create_evaluation_dataframe(
    model_name="Baseline Model", variation="Weights | Grayscale=F | Contrast=F | Saturation=T | Adam=0.001",
    train_metrics=train_results, val_metrics=val_results, test_metrics=test_results, train_time=train_time,
    csv_save_path= f"./ModelsEvaluation/2_BaselineModel_TrainingValidationMetrics_{model_name}.csv"
)
display_side_by_side(results_df, super_title="Model Evaluation Results")
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 17s 924ms/step - accuracy: 0.0960 - auc: 0.7450 - f1_score: 0.0355 - loss: 4.7572 - precision: 0.0000e+00 - recall: 0.0000e+00
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 18s 948ms/step - accuracy: 0.0845 - auc: 0.7548 - f1_score: 0.0284 - loss: 4.7405 - precision: 0.0000e+00 - recall: 0.0000e+00
# <h1 style="text-align: left; margin-bottom: -15px;">Model Evaluation Results</h1><br><div style="display: flex;"><div style="margin-right: 20px;"><h3 style="text-align: center;color:#555555;"></h3><table style="display:inline; margin-right: 20px;" border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th colspan="5" halign="left">Train</th>
#       <th colspan="5" halign="left">Validation</th>
#       <th colspan="5" halign="left">Test</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>Time of Execution</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1 Score</th>
#       <th>AUROC</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1 Score</th>
#       <th>AUROC</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1 Score</th>
#       <th>AUROC</th>
#     </tr>
#     <tr>
#       <th>Model</th>
#       <th>Variation</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Baseline Model</th>
#       <th>Weights | Grayscale=F | Contrast=F | Saturation=T | Adam=0.001</th>
#       <td>1822.11</td>
#       <td>0.0787</td>
#       <td>0.4815</td>
#       <td>0.0027</td>
#       <td>0.0523</td>
#       <td>0.7896</td>
#       <td>0.0801</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0618</td>
#       <td>0.7574</td>
#       <td>0.0617</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0429</td>
#       <td>0.7616</td>
#     </tr>
#   </tbody>
# </table style="display:inline; margin-right: 20px;"></div></div>

# %% [markdown]
# ---

# %% [markdown]
# ## **📊 Best Model - Predictions Analysis**

# %%
from utilities import plot_confusion_matrix

# Plot confusion matrix for test set
plot_confusion_matrix(
    y_true=test_datagen.classes,
    y_pred=model.predict(test_datagen, batch_size=batch_size),
    title="Confusion Matrix | Best Baseline Model",
    file_path="./ModelsEvaluation/3_TestConfusionMatrix_BestBaselineModel.png",
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-e452b67dad50> in <cell line: 0>()
#       3 # Plot confusion matrix for test set
#       4 plot_confusion_matrix(
# ----> 5     y_true=test_datagen.classes,
#       6     y_pred=model.predict(test_datagen, batch_size=batch_size),
#       7     title="Confusion Matrix | Best Baseline Model",
#
# AttributeError: '_PrefetchDataset' object has no attribute 'classes'

# %%
# Plot 5 right and 5 wrong predictions
from utilities import plot_predictions
plot_predictions(
    model=model,
    data=test_datagen,
    n_samples=5,
    file_path="./ModelsEvaluation/4_TestPredictions_BestBaselineModel.png"
)

# %% [markdown]
# ---

# %%
# Save Collab Workspace
# !zip -r /content/ModelCallbacks.zip /content/ModelCallbacks

# %%
# !zip -r /content/ModelsEvaluation.zip /content/ModelsEvaluation

# %%
from google.colab import files
files.download("/content/ModelCallbacks.zip")

# %%
files.download("/content/ModelsEvaluation.zip")

# %% [markdown]
# ---

# %% [markdown]
# # **🔗 Bibliography/References**
#
# **[[1]](https://)** AAAAAAAAAA
#
# ---
